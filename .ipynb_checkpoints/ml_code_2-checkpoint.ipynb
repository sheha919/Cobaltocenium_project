# %% [markdown]
# <a href="https://colab.research.google.com/github/sheha919/Cobaltocenium_project/blob/main/ml_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D



from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn import set_config
set_config(display='diagram')
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA

# Keras
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras import metrics
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping

# %%
df=pd.read_excel('/content/cobaltocenium_data.xlsx')
df.head()
# Out:
#    Unnamed: 0                           Name  Co[CpY][CpY']OH energy (Eh)  \
# 0           0   Co(Cp-N(CH₃)₂)(Cp-N(CH₃)₂)OH                 -2113.503825
# 1           1      Co(Cp-N(CH₃)₂)(Cp-OCH₃)OH                 -2094.048389
# 2           2  Co(Cp-N(CH₃)₂)(Cp-O(CO)CH₃)OH                 -2207.402596
# 3           3   Co(Cp-N(CH₃)₂)(Cp-P(CH₃)₂)OH                 -2400.122408
# 4           4    Co(Cp-N(CH₃)₂)(Cp-S(CH₃))OH                 -2417.026291
#
#   CoCpY' name  CoCpY'energy (Eh) CpY name  CpY energy (Eh)  BDE (kcal/mol)  \
# 0     N(CH₃)₂       -1785.987408  N(CH₃)₂      -327.488954       17.233174
# 1        OCH₃       -1766.531474  N(CH₃)₂      -327.488954       17.545539
# 2    O(CO)CH₃       -1879.885018  N(CH₃)₂      -327.488954       17.961810
# 3     P(CH₃)₂       -2072.607246  N(CH₃)₂      -327.488954       16.445457
# 4      S(CH₃)       -2089.514536  N(CH₃)₂      -327.488954       14.308038
#
#    Dipole moment(Debye)  EHOMO(Co[CpY][CpY']OH) (Eh)  ...  \
# 0               15.5954                      -0.1803  ...
# 1               14.9760                      -0.1867  ...
# 2               18.7135                      -0.1849  ...
# 3               19.9044                      -0.1862  ...
# 4               14.9101                      -0.1868  ...
#
#    ELUMO(CoCpY'OH) (Eh)  EHOMO(CpY) (Eh)  ELUMO(CpY) (Eh)  \
# 0               -0.0719          -0.1594          -0.0809
# 1               -0.0727          -0.1594          -0.0809
# 2               -0.0855          -0.1594          -0.0809
# 3               -0.0814          -0.1594          -0.0809
# 4               -0.0817          -0.1594          -0.0809
#
#    CoCpY' Hirshfeld charge  CpY Hirshfeld charge  CoCpY' polarizability  \
# 0                 0.011840               0.01184               27.53932
# 1                -0.015190               0.01184               18.01558
# 2                 0.071736               0.01184               27.13368
# 3                -0.059590               0.01184               43.11939
# 4                 0.019722               0.01184               27.96205
#
#    CpY polarizability  Hardness (kcal/mol)  dCOM (Å)  rCo-O (Å)
# 0            27.53932           -39.156000  3.337480   3.856084
# 1            27.53932           -39.532500  3.314513   4.150980
# 2            27.53932           -37.085250  3.312872   4.065847
# 3            27.53932           -37.744125  3.333984   4.033683
# 4            27.53932           -38.089250  3.328151   3.818543
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 903 entries, 0 to 902
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   903 non-null    int64
#  1   Name                         903 non-null    object
#  2   Co[CpY][CpY']OH energy (Eh)  903 non-null    float64
#  3   CoCpY' name                  903 non-null    object
#  4   CoCpY'energy (Eh)            903 non-null    float64
#  5   CpY name                     903 non-null    object
#  6   CpY energy (Eh)              903 non-null    float64
#  7   BDE (kcal/mol)               903 non-null    float64
#  8   Dipole moment(Debye)         903 non-null    float64
#  9   EHOMO(Co[CpY][CpY']OH) (Eh)  903 non-null    float64
#  10  ELUMO(Co[CpY][CpY']OH) (Eh)  903 non-null    float64
#  11  EHOMO(CoCpY'OH) (Eh)         903 non-null    float64
#  12  ELUMO(CoCpY'OH) (Eh)         903 non-null    float64
#  13  EHOMO(CpY) (Eh)              903 non-null    float64
#  14  ELUMO(CpY) (Eh)              903 non-null    float64
#  15  CoCpY' Hirshfeld charge      903 non-null    float64
#  16  CpY Hirshfeld charge         903 non-null    float64
#  17  CoCpY' polarizability        903 non-null    float64
#  18  CpY polarizability           903 non-null    float64
#  19  Hardness (kcal/mol)          903 non-null    float64
#  20  dCOM (Å)                     903 non-null    float64
#  21  rCo-O (Å)                    903 non-null    float64
# dtypes: float64(18), int64(1), object(3)
# memory usage: 155.3+ KB

# %%
ml_df=df.copy()

# %%
ml_df=ml_df.drop(columns=['Unnamed: 0'], axis = 1)
ml_df.head()
# Out:
#                             Name  Co[CpY][CpY']OH energy (Eh) CoCpY' name  \
# 0   Co(Cp-N(CH₃)₂)(Cp-N(CH₃)₂)OH                 -2113.503825     N(CH₃)₂
# 1      Co(Cp-N(CH₃)₂)(Cp-OCH₃)OH                 -2094.048389        OCH₃
# 2  Co(Cp-N(CH₃)₂)(Cp-O(CO)CH₃)OH                 -2207.402596    O(CO)CH₃
# 3   Co(Cp-N(CH₃)₂)(Cp-P(CH₃)₂)OH                 -2400.122408     P(CH₃)₂
# 4    Co(Cp-N(CH₃)₂)(Cp-S(CH₃))OH                 -2417.026291      S(CH₃)
#
#    CoCpY'energy (Eh) CpY name  CpY energy (Eh)  BDE (kcal/mol)  \
# 0       -1785.987408  N(CH₃)₂      -327.488954       17.233174
# 1       -1766.531474  N(CH₃)₂      -327.488954       17.545539
# 2       -1879.885018  N(CH₃)₂      -327.488954       17.961810
# 3       -2072.607246  N(CH₃)₂      -327.488954       16.445457
# 4       -2089.514536  N(CH₃)₂      -327.488954       14.308038
#
#    Dipole moment(Debye)  EHOMO(Co[CpY][CpY']OH) (Eh)  \
# 0               15.5954                      -0.1803
# 1               14.9760                      -0.1867
# 2               18.7135                      -0.1849
# 3               19.9044                      -0.1862
# 4               14.9101                      -0.1868
#
#    ELUMO(Co[CpY][CpY']OH) (Eh)  ...  ELUMO(CoCpY'OH) (Eh)  EHOMO(CpY) (Eh)  \
# 0                      -0.0555  ...               -0.0719          -0.1594
# 1                      -0.0607  ...               -0.0727          -0.1594
# 2                      -0.0667  ...               -0.0855          -0.1594
# 3                      -0.0659  ...               -0.0814          -0.1594
# 4                      -0.0654  ...               -0.0817          -0.1594
#
#    ELUMO(CpY) (Eh)  CoCpY' Hirshfeld charge  CpY Hirshfeld charge  \
# 0          -0.0809                 0.011840               0.01184
# 1          -0.0809                -0.015190               0.01184
# 2          -0.0809                 0.071736               0.01184
# 3          -0.0809                -0.059590               0.01184
# 4          -0.0809                 0.019722               0.01184
#
#    CoCpY' polarizability  CpY polarizability  Hardness (kcal/mol)  dCOM (Å)  \
# 0               27.53932            27.53932           -39.156000  3.337480
# 1               18.01558            27.53932           -39.532500  3.314513
# 2               27.13368            27.53932           -37.085250  3.312872
# 3               43.11939            27.53932           -37.744125  3.333984
# 4               27.96205            27.53932           -38.089250  3.328151
#
#    rCo-O (Å)
# 0   3.856084
# 1   4.150980
# 2   4.065847
# 3   4.033683
# 4   3.818543
#
# [5 rows x 21 columns]

# %% [markdown]
# #Filter Data

# %%
#BDE data greater than 3kcal/mol
drop_bde = (ml_df[ml_df['BDE (kcal/mol)']<=3])
len(drop_bde)
# Out:
# 30

# %%
drop_bde['Name']
# Out:
# 290            Co(Cp-C₂H)(Cp-CBr₃)OH
# 450             Co(Cp-Cl)(Cp-CBr₃)OH
# 479             Co(Cp-Br)(Cp-CBr₃)OH
# 507              Co(Cp-F)(Cp-CBr₃)OH
# 534      Co(Cp-(CO)NHCH₃)(Cp-CBr₃)OH
# 585       Co(Cp-(CO)OCH₃)(Cp-CBr₃)OH
# 632          Co(Cp-(CO)H)(Cp-CBr₃)OH
# 651        Co(Cp-(CO)F)(Cp-(CO)Cl)OH
# 654          Co(Cp-(CO)F)(Cp-CBr₃)OH
# 657           Co(Cp-(CO)F)(Cp-NO₂)OH
# 658        Co(Cp-(CO)F)(Cp-SOOCF₃)OH
# 672       Co(Cp-(CO)Cl)(Cp-(CO)Cl)OH
# 675         Co(Cp-(CO)Cl)(Cp-CBr₃)OH
# 676           Co(Cp-(CO)Cl)(Cp-CN)OH
# 678          Co(Cp-(CO)Cl)(Cp-NO₂)OH
# 679       Co(Cp-(CO)Cl)(Cp-SOOCF₃)OH
# 695            Co(Cp-CF₃)(Cp-CBr₃)OH
# 714           Co(Cp-CCl₃)(Cp-CBr₃)OH
# 732           Co(Cp-CBr₃)(Cp-CBr₃)OH
# 733             Co(Cp-CBr₃)(Cp-CN)OH
# 734         Co(Cp-CBr₃)(Cp-SOOCH₃)OH
# 735            Co(Cp-CBr₃)(Cp-NO₂)OH
# 736         Co(Cp-CBr₃)(Cp-SOOCF₃)OH
# 740        Co(Cp-CBr₃)(Cp-o-PhCF₃)OH
# 745    Co(Cp-CBr₃)(Cp-op-Ph(CH₃)₃)OH
# 752              Co(Cp-CN)(Cp-NO₂)OH
# 753           Co(Cp-CN)(Cp-SOOCF₃)OH
# 783             Co(Cp-NO₂)(Cp-NO₂)OH
# 784          Co(Cp-NO₂)(Cp-SOOCF₃)OH
# 798       Co(Cp-SOOCF₃)(Cp-SOOCF₃)OH
# Name: Name, dtype: object

# %%
ml_df = ml_df[ml_df['BDE (kcal/mol)']>3]
len(ml_df)
# Out:
# 873

# %%
frag = ml_df[["Name", "CoCpY' name", "CpY name", 
              "BDE (kcal/mol)",
              "EHOMO(CoCpY'OH) (Eh)", "ELUMO(CoCpY'OH) (Eh)", 
              "EHOMO(CpY) (Eh)", "ELUMO(CpY) (Eh)", 
              "CoCpY' Hirshfeld charge", "CpY Hirshfeld charge",
              "CoCpY' polarizability", "CpY polarizability"]]
frag.head()
# Out:
#                             Name CoCpY' name CpY name  BDE (kcal/mol)  \
# 0   Co(Cp-N(CH₃)₂)(Cp-N(CH₃)₂)OH     N(CH₃)₂  N(CH₃)₂       17.233174
# 1      Co(Cp-N(CH₃)₂)(Cp-OCH₃)OH        OCH₃  N(CH₃)₂       17.545539
# 2  Co(Cp-N(CH₃)₂)(Cp-O(CO)CH₃)OH    O(CO)CH₃  N(CH₃)₂       17.961810
# 3   Co(Cp-N(CH₃)₂)(Cp-P(CH₃)₂)OH     P(CH₃)₂  N(CH₃)₂       16.445457
# 4    Co(Cp-N(CH₃)₂)(Cp-S(CH₃))OH      S(CH₃)  N(CH₃)₂       14.308038
#
#    EHOMO(CoCpY'OH) (Eh)  ELUMO(CoCpY'OH) (Eh)  EHOMO(CpY) (Eh)  \
# 0               -0.1787               -0.0719          -0.1594
# 1               -0.1935               -0.0727          -0.1594
# 2               -0.2170               -0.0855          -0.1594
# 3               -0.2133               -0.0814          -0.1594
# 4               -0.2015               -0.0817          -0.1594
#
#    ELUMO(CpY) (Eh)  CoCpY' Hirshfeld charge  CpY Hirshfeld charge  \
# 0          -0.0809                 0.011840               0.01184
# 1          -0.0809                -0.015190               0.01184
# 2          -0.0809                 0.071736               0.01184
# 3          -0.0809                -0.059590               0.01184
# 4          -0.0809                 0.019722               0.01184
#
#    CoCpY' polarizability  CpY polarizability
# 0               27.53932            27.53932
# 1               18.01558            27.53932
# 2               27.13368            27.53932
# 3               43.11939            27.53932
# 4               27.96205            27.53932

# %%
corr = abs(frag.corr())
plt.figure(figsize=[16,14])
sns.heatmap(corr, cmap="YlGnBu",  vmin=0.0, vmax=1.0,annot = True, annot_kws={'size': 15})
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.title('Correlation between features related to fragments', fontsize = 18, fontweight = 'bold');

# %% [markdown]
# #Statistics

# %%
ml_df.describe()
# Out:
#        Co[CpY][CpY']OH energy (Eh)  CoCpY'energy (Eh)  CpY energy (Eh)  \
# count                   873.000000         873.000000       873.000000
# mean                  -2885.015296       -2078.544199      -806.446835
# std                    1343.930437         778.250606      1106.634781
# min                  -10408.735637       -9411.126546     -7952.631083
# 25%                   -2880.695616       -2220.117477      -768.161154
# 50%                   -2567.428016       -1879.885018      -542.529457
# 75%                   -2283.371861       -1766.531474      -397.996994
# max                   -1845.520993       -1652.003971      -193.474683
#
#        BDE (kcal/mol)  Dipole moment(Debye)  EHOMO(Co[CpY][CpY']OH) (Eh)  \
# count      873.000000            873.000000                   873.000000
# mean        15.224432             16.170617                    -0.191159
# std          6.629545              3.231558                     0.006312
# min          3.185810              4.493000                    -0.223500
# 25%         10.742214             14.038600                    -0.191500
# 50%         14.245329             16.331700                    -0.190000
# 75%         18.345363             18.211100                    -0.188400
# max         42.413274             27.728700                    -0.180300
#
#        ELUMO(Co[CpY][CpY']OH) (Eh)  EHOMO(CoCpY'OH) (Eh)  \
# count                   873.000000            873.000000
# mean                     -0.086005             -0.214888
# std                       0.011437              0.013198
# min                      -0.118800             -0.237800
# 25%                      -0.093000             -0.224500
# 50%                      -0.084900             -0.213300
# 75%                      -0.078200             -0.204500
# max                      -0.054800             -0.171600
#
#        ELUMO(CoCpY'OH) (Eh)  EHOMO(CpY) (Eh)  ELUMO(CpY) (Eh)  \
# count            873.000000       873.000000       873.000000
# mean              -0.085469        -0.200897        -0.117825
# std                0.008885         0.021833         0.016527
# min               -0.106800        -0.246900        -0.151300
# 25%               -0.092000        -0.216600        -0.125000
# 50%               -0.085100        -0.201000        -0.118300
# 75%               -0.079400        -0.188600        -0.112600
# max               -0.063300        -0.155200        -0.076800
#
#        CoCpY' Hirshfeld charge  CpY Hirshfeld charge  CoCpY' polarizability  \
# count               873.000000            873.000000             873.000000
# mean                  0.034738              0.020129              32.582851
# std                   0.062240              0.050861              29.889890
# min                  -0.081960             -0.081960               0.265420
# 25%                  -0.024960             -0.015190              12.952910
# 50%                   0.038080              0.011965              24.041310
# 75%                   0.081263              0.057107              43.981350
# max                   0.160449              0.160449             150.643000
#
#        CpY polarizability  Hardness (kcal/mol)    dCOM (Å)   rCo-O (Å)
# count          873.000000           873.000000  873.000000  873.000000
# mean            48.667438           -32.992052    3.300790    4.008424
# std             33.700939             3.965526    0.010104    0.159475
# min              0.265420           -46.529125    3.282637    3.691918
# 25%             22.669890           -35.328250    3.292941    3.896393
# 50%             52.745580           -33.100625    3.298622    3.994029
# 75%             60.200450           -30.465125    3.305980    4.104762
# max            150.643000           -22.935125    3.337480    4.725310

# %%
#checking for duplicates
ml_df.duplicated().sum()
# Out:
# 0

# %%
#checking for missing values
ml_df.isna().sum().sum()
# Out:
# 0

# %%
ml_df.head()
# Out:
#                             Name  Co[CpY][CpY']OH energy (Eh) CoCpY' name  \
# 0   Co(Cp-N(CH₃)₂)(Cp-N(CH₃)₂)OH                 -2113.503825     N(CH₃)₂
# 1      Co(Cp-N(CH₃)₂)(Cp-OCH₃)OH                 -2094.048389        OCH₃
# 2  Co(Cp-N(CH₃)₂)(Cp-O(CO)CH₃)OH                 -2207.402596    O(CO)CH₃
# 3   Co(Cp-N(CH₃)₂)(Cp-P(CH₃)₂)OH                 -2400.122408     P(CH₃)₂
# 4    Co(Cp-N(CH₃)₂)(Cp-S(CH₃))OH                 -2417.026291      S(CH₃)
#
#    CoCpY'energy (Eh) CpY name  CpY energy (Eh)  BDE (kcal/mol)  \
# 0       -1785.987408  N(CH₃)₂      -327.488954       17.233174
# 1       -1766.531474  N(CH₃)₂      -327.488954       17.545539
# 2       -1879.885018  N(CH₃)₂      -327.488954       17.961810
# 3       -2072.607246  N(CH₃)₂      -327.488954       16.445457
# 4       -2089.514536  N(CH₃)₂      -327.488954       14.308038
#
#    Dipole moment(Debye)  EHOMO(Co[CpY][CpY']OH) (Eh)  \
# 0               15.5954                      -0.1803
# 1               14.9760                      -0.1867
# 2               18.7135                      -0.1849
# 3               19.9044                      -0.1862
# 4               14.9101                      -0.1868
#
#    ELUMO(Co[CpY][CpY']OH) (Eh)  ...  ELUMO(CoCpY'OH) (Eh)  EHOMO(CpY) (Eh)  \
# 0                      -0.0555  ...               -0.0719          -0.1594
# 1                      -0.0607  ...               -0.0727          -0.1594
# 2                      -0.0667  ...               -0.0855          -0.1594
# 3                      -0.0659  ...               -0.0814          -0.1594
# 4                      -0.0654  ...               -0.0817          -0.1594
#
#    ELUMO(CpY) (Eh)  CoCpY' Hirshfeld charge  CpY Hirshfeld charge  \
# 0          -0.0809                 0.011840               0.01184
# 1          -0.0809                -0.015190               0.01184
# 2          -0.0809                 0.071736               0.01184
# 3          -0.0809                -0.059590               0.01184
# 4          -0.0809                 0.019722               0.01184
#
#    CoCpY' polarizability  CpY polarizability  Hardness (kcal/mol)  dCOM (Å)  \
# 0               27.53932            27.53932           -39.156000  3.337480
# 1               18.01558            27.53932           -39.532500  3.314513
# 2               27.13368            27.53932           -37.085250  3.312872
# 3               43.11939            27.53932           -37.744125  3.333984
# 4               27.96205            27.53932           -38.089250  3.328151
#
#    rCo-O (Å)
# 0   3.856084
# 1   4.150980
# 2   4.065847
# 3   4.033683
# 4   3.818543
#
# [5 rows x 21 columns]

# %%
ml_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 873 entries, 0 to 902
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name                         873 non-null    object
#  1   Co[CpY][CpY']OH energy (Eh)  873 non-null    float64
#  2   CoCpY' name                  873 non-null    object
#  3   CoCpY'energy (Eh)            873 non-null    float64
#  4   CpY name                     873 non-null    object
#  5   CpY energy (Eh)              873 non-null    float64
#  6   BDE (kcal/mol)               873 non-null    float64
#  7   Dipole moment(Debye)         873 non-null    float64
#  8   EHOMO(Co[CpY][CpY']OH) (Eh)  873 non-null    float64
#  9   ELUMO(Co[CpY][CpY']OH) (Eh)  873 non-null    float64
#  10  EHOMO(CoCpY'OH) (Eh)         873 non-null    float64
#  11  ELUMO(CoCpY'OH) (Eh)         873 non-null    float64
#  12  EHOMO(CpY) (Eh)              873 non-null    float64
#  13  ELUMO(CpY) (Eh)              873 non-null    float64
#  14  CoCpY' Hirshfeld charge      873 non-null    float64
#  15  CpY Hirshfeld charge         873 non-null    float64
#  16  CoCpY' polarizability        873 non-null    float64
#  17  CpY polarizability           873 non-null    float64
#  18  Hardness (kcal/mol)          873 non-null    float64
#  19  dCOM (Å)                     873 non-null    float64
#  20  rCo-O (Å)                    873 non-null    float64
# dtypes: float64(18), object(3)
# memory usage: 150.0+ KB

# %% [markdown]
# #Validate Split

# %%
y = ml_df['BDE (kcal/mol)']
X = ml_df[["EHOMO(CoCpY'OH) (Eh)", "ELUMO(CoCpY'OH) (Eh)", "EHOMO(CpY) (Eh)", "ELUMO(CpY) (Eh)", "CoCpY' Hirshfeld charge", "CpY Hirshfeld charge"]]

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
X_train
# Out:
#      EHOMO(CoCpY'OH) (Eh)  ELUMO(CoCpY'OH) (Eh)  EHOMO(CpY) (Eh)  \
# 430               -0.2131               -0.0789          -0.2027
# 79                -0.1956               -0.0633          -0.1886
# 148               -0.2133               -0.0814          -0.2469
# 409               -0.2131               -0.0789          -0.2190
# 440               -0.2121               -0.0807          -0.2198
# ..                    ...                   ...              ...
# 106               -0.2297               -0.0944          -0.2092
# 270               -0.2003               -0.0802          -0.1552
# 890               -0.2060               -0.0794          -0.1552
# 436               -0.2131               -0.0789          -0.1952
# 102               -0.2346               -0.0965          -0.2092
#
#      ELUMO(CpY) (Eh)  CoCpY' Hirshfeld charge  CpY Hirshfeld charge
# 430          -0.1250                -0.050620              0.024095
# 79           -0.1003                -0.041080             -0.015190
# 148          -0.1496                -0.059590              0.132226
# 409          -0.1256                -0.050620              0.083209
# 440          -0.1243                 0.079571              0.084139
# ..               ...                      ...                   ...
# 106          -0.1170                 0.156189              0.071736
# 270          -0.0768                 0.008470             -0.081960
# 890          -0.0768                -0.042140             -0.081960
# 436          -0.1163                -0.050620             -0.040350
# 102          -0.1170                 0.121657              0.071736
#
# [654 rows x 6 columns]

# %% [markdown]
# #Functions

# %% [markdown]
# ## Evaluvation

# %%
#function for evaluation
def eval_model(pipe, X_train=X_train, y_train=y_train, X_test=X_test , y_test= y_test):
  eval_results = pd.DataFrame(columns = ['Metrics','Train Score', 'Test Score'])
  train_mae = mean_absolute_error(y_train, pipe.predict(X_train))
  test_mae = mean_absolute_error(y_test, pipe.predict(X_test))

  train_mse = mean_squared_error(y_train, pipe.predict(X_train))
  test_mse = mean_squared_error(y_test, pipe.predict(X_test))

  train_rmse = np.sqrt(train_mse)
  test_rmse = np.sqrt(test_mse)

  train_r2 = r2_score(y_train, pipe.predict(X_train))
  test_r2 = r2_score(y_test, pipe.predict(X_test))

  eval_results.loc[1, 'Metrics'] = 'MAE'
  eval_results.loc[2, 'Metrics'] = 'MSE'
  eval_results.loc[3, 'Metrics'] = 'RMSE'
  eval_results.loc[4, 'Metrics'] = 'R2'

  eval_results.loc[1, 'Train Score'] = train_mae
  eval_results.loc[2, 'Train Score'] = train_mse
  eval_results.loc[3, 'Train Score'] = train_rmse
  eval_results.loc[4, 'Train Score'] = train_r2

  eval_results.loc[1, 'Test Score'] = test_mae
  eval_results.loc[2, 'Test Score'] = test_mse
  eval_results.loc[3, 'Test Score'] = test_rmse
  eval_results.loc[4, 'Test Score'] = test_r2

  return eval_results

# %%
#function for final evaluation
def eval_model_final(pipe, 
                     X_train=X_train, y_train=y_train, 
                     X_test=X_test , y_test= y_test):

  train_mse = mean_squared_error(y_train, pipe.predict(X_train))
  test_mse = mean_squared_error(y_test, pipe.predict(X_test))

  train_rmse = np.sqrt(train_mse)
  test_rmse = np.sqrt(test_mse)

  train_r2 = r2_score(y_train, pipe.predict(X_train))
  test_r2 = r2_score(y_test, pipe.predict(X_test))

  return (round(train_r2,6), round(test_r2,6), round(train_rmse,6), round(test_rmse,6))

# %% [markdown]
# ## Plot

# %%
def train_test_plot(model_name, pipe,  X_train=X_train, y_train=y_train, X_test=X_test , y_test= y_test):
  fig, axes = plt.subplots(nrows = 1, ncols=2, figsize=(12,4))
#subplot1
  ax = sns.regplot(x = y_train, 
                   y = pipe.predict(X_train), 
                   line_kws = {'color':'black', 'ls': ':', 'label' :f'R$^2$ = {round(r2_score(y_train, pipe.predict(X_train)), 6)}'}, 
                   ax=axes[0],
                   )
  axes[0].set_title('Train Data', fontweight = 'bold')
  axes[0].set_xlabel('Actual BDE (kcal/mol)')
  axes[0].set_ylabel('Predicted BDE (kcal/mol)');

#subplot2
  ax = sns.regplot(x = y_test, 
                   y = pipe.predict(X_test), 
                   line_kws = {'color':'black', 'ls': ':', 
                   'label' : f'R$^2$ = {round(r2_score(y_test, pipe.predict(X_test)), 6)}'}, 
                   ax=axes[1])
  axes[1].set_title('Test Data', fontweight = 'bold')
  axes[1].set_xlabel('Actual BDE (kcal/mol)')
  axes[1].set_ylabel('Predicted BDE (kcal/mol)')
  
  fig.suptitle(f'Train and Test Results of {model_name}', fontsize = 20, fontweight = 'bold', y = 1.1)
  [ax.legend() for ax in axes];
  return (fig, axes)

# %% [markdown]
# #Data Preprocessing

# %% [markdown]
# ## Instantiate colimn transformers

# %%
scaler = StandardScaler()

# %% [markdown]
# # Linear Regression Model

# %%
lr = LinearRegression()
lr_pipe = make_pipeline(scaler, lr)
lr_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %%
#evaluvation of linear rigression
eval_model(lr_pipe)
# Out:
#   Metrics Train Score Test Score
# 1     MAE    2.979453   3.068536
# 2     MSE   23.590921  26.731918
# 3    RMSE    4.857049   5.170292
# 4      R2    0.459858   0.400263

# %%
train_test_plot('Linear Regression Model', lr_pipe)
# Out:
# (<Figure size 864x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd1581fd700>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd15822d190>],
#        dtype=object))

# %% [markdown]
# #Decision Tree Model

# %%
dt = DecisionTreeRegressor(random_state = 42)
dt_pipe = make_pipeline(scaler, dt)
dt_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('decisiontreeregressor',
#                  DecisionTreeRegressor(random_state=42))])

# %%
#evaluvation of initial decision tree
eval_model(dt_pipe)
# Out:
#   Metrics Train Score Test Score
# 1     MAE         0.0   2.297034
# 2     MSE         0.0  22.243441
# 3    RMSE         0.0   4.716295
# 4      R2         1.0   0.500963

# %%
train_test_plot('Initial Decision Tree Model', dt_pipe)
# Out:
# (<Figure size 864x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd15813d550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd1580ff970>],
#        dtype=object))

# %% [markdown]
# #Bagged Tree Model

# %%
bt = BaggingRegressor(random_state = 42)
bt_pipe = make_pipeline(scaler, bt)
bt_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('baggingregressor', BaggingRegressor(random_state=42))])

# %%
#evaluvation of initial bagged tree
eval_model(bt_pipe)
# Out:
#   Metrics Train Score Test Score
# 1     MAE    0.662925   1.870592
# 2     MSE    1.373204  10.762181
# 3    RMSE    1.171838   3.280576
# 4      R2    0.968559   0.758548

# %%
train_test_plot('Initial Bagged Tree Model', bt_pipe)
# Out:
# (<Figure size 864x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd158171d60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd1582a86a0>],
#        dtype=object))

# %% [markdown]
# # K-Nearest Neighbors Model

# %%
knn = KNeighborsRegressor()
knn_pipe = make_pipeline(scaler, knn)
knn_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('kneighborsregressor', KNeighborsRegressor())])

# %%
#evaluvation of initial knn
eval_model(knn_pipe)
# Out:
#   Metrics Train Score Test Score
# 1     MAE    2.202204   3.136901
# 2     MSE   13.104078  25.464302
# 3    RMSE    3.619956   5.046217
# 4      R2    0.699967   0.428702

# %%
train_test_plot('Initial KNN Model', knn_pipe)
# Out:
# (<Figure size 864x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd157ff2b80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd157f87640>],
#        dtype=object))

# %% [markdown]
# # Random Forest Model

# %%
rf = RandomForestRegressor(random_state= 42)
rf_pipe = make_pipeline(scaler, rf)
rf_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestregressor',
#                  RandomForestRegressor(random_state=42))])

# %%
#evaluvation of initial bagged tree
eval_model(rf_pipe)
# Out:
#   Metrics Train Score Test Score
# 1     MAE    0.536732   1.703929
# 2     MSE    0.782414   9.134505
# 3    RMSE    0.884542   3.022334
# 4      R2    0.982086   0.795065

# %%
train_test_plot('Initial Random Forest Model', rf_pipe)
# Out:
# (<Figure size 864x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd157ecdd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd157ef1580>],
#        dtype=object))

# %% [markdown]
# #Support Vector Regression Model

# %%
svg = SVR()
svg_pipe = make_pipeline(scaler, svg)
svg_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('svr', SVR())])

# %%
#evaluvation of initial svg
eval_model(svg_pipe)
# Out:
#   Metrics Train Score Test Score
# 1     MAE    2.702287   2.966963
# 2     MSE   22.741897  27.702162
# 3    RMSE    4.768846   5.263284
# 4      R2    0.479298   0.378495

# %%
train_test_plot('Initial SVG Model', svg_pipe)
# Out:
# (<Figure size 864x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd157e55e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd157dc9d60>],
#        dtype=object))

# %% [markdown]
# # XG Boost

# %%
xgb = XGBRegressor(random_state= 42)
xgb_pipe = make_pipeline(scaler, xgb)
xgb_pipe.fit(X_train, y_train)
# Out:
# [22:10:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('xgbregressor', XGBRegressor(random_state=42))])

# %%
#evaluvation of initial xgb
eval_model(xgb_pipe)
# Out:
#   Metrics Train Score Test Score
# 1     MAE    1.267446   1.594116
# 2     MSE    4.147594   6.951909
# 3    RMSE    2.036564   2.636647
# 4      R2    0.905036   0.844032

# %%
train_test_plot('Initial XG Boost Model', xgb_pipe)
# Out:
# (<Figure size 864x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd14ce6a0d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd14ce40190>],
#        dtype=object))

# %% [markdown]
# #Evaluvation of initial models

# %%
model = ['Linear Regression', 'Decision Tree', 'Bagged Tree', 'KNN', 'Random Forest', 'SVG', 'XG Boost']
pipe = [lr_pipe, dt_pipe, bt_pipe, knn_pipe, rf_pipe, svg_pipe, xgb_pipe]
final_eval_results = pd.DataFrame(columns = ['Model','Train R2', 'Test R2', 'Train RMSE (kcal/mol)', 'Test RMSE (kcal/mol)'])

for i in range(len(model)):
  final_eval_results.loc[i, 'Model'] = model[i]
  final_eval_results.loc[i,'Train R2'], final_eval_results.loc[i,'Test R2'], final_eval_results.loc[i,'Train RMSE (kcal/mol)'], final_eval_results.loc[i,'Test RMSE (kcal/mol)'] = eval_model_final(pipe[i])

# %%
final_eval_results.set_index('Model', inplace = True) 
final_eval_results
# Out:
#                    Train R2   Test R2 Train RMSE (kcal/mol)  \
# Model
# Linear Regression  0.459858  0.400263              4.857049
# Decision Tree           1.0  0.500963                   0.0
# Bagged Tree        0.968559  0.758548              1.171838
# KNN                0.699967  0.428702              3.619956
# Random Forest      0.982086  0.795065              0.884542
# SVG                0.479298  0.378495              4.768846
# XG Boost           0.905036  0.844032              2.036564
#
#                   Test RMSE (kcal/mol)
# Model
# Linear Regression             5.170292
# Decision Tree                 4.716295
# Bagged Tree                   3.280576
# KNN                           5.046217
# Random Forest                 3.022334
# SVG                           5.263284
# XG Boost                      2.636647

# %% [markdown]
# - According to the train and test RMSE values for the models;
#   - all models have overfilling issue and decision tree has the highest overfittin problem.
# - Out of these 7 models, XG boost, random forest and bagged tree are selected based on the test R$^2$ score to do further optimizations.

# %% [markdown]
# #Tunning Hyperparametrs and cross validation of models

# %% [markdown]
# ## For XG Boost

# %%
#parametrs of XG boost model
xgb_pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('standardscaler', StandardScaler()),
#   ('xgbregressor', XGBRegressor(random_state=42))],
#  'verbose': False,
#  'standardscaler': StandardScaler(),
#  'xgbregressor': XGBRegressor(random_state=42),
#  'standardscaler__copy': True,
#  'standardscaler__with_mean': True,
#  'standardscaler__with_std': True,
#  'xgbregressor__base_score': 0.5,
#  'xgbregressor__booster': 'gbtree',
#  'xgbregressor__colsample_bylevel': 1,
#  'xgbregressor__colsample_bynode': 1,
#  'xgbregressor__colsample_bytree': 1,
#  'xgbregressor__gamma': 0,
#  'xgbregressor__importance_type': 'gain',
#  'xgbregressor__learning_rate': 0.1,
#  'xgbregressor__max_delta_step': 0,
#  'xgbregressor__max_depth': 3,
#  'xgbregressor__min_child_weight': 1,
#  'xgbregressor__missing': None,
#  'xgbregressor__n_estimators': 100,
#  'xgbregressor__n_jobs': 1,
#  'xgbregressor__nthread': None,
#  'xgbregressor__objective': 'reg:linear',
#  'xgbregressor__random_state': 42,
#  'xgbregressor__reg_alpha': 0,
#  'xgbregressor__reg_lambda': 1,
#  'xgbregressor__scale_pos_weight': 1,
#  'xgbregressor__seed': None,
#  'xgbregressor__silent': None,
#  'xgbregressor__subsample': 1,
#  'xgbregressor__verbosity': 1}

# %%
xgb_param_grid = {'xgbregressor__max_depth': [2, 3, 4, 5, 6 ],
                  'xgbregressor__n_estimators': [75, 100, 250, 500, 600, 700, 800, 900, 1000]}

# %%
xgb_pipe_gs = GridSearchCV(xgb_pipe, xgb_param_grid, cv=5)
xgb_pipe_gs.fit(X_train, y_train)
# Out:
# [22:10:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22
,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd14cd4ce80>],
#        dtype=object))

# %% [markdown]
# ## For Random Forest

# %%
#parametrs of random forest model
rf_pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('standardscaler', StandardScaler()),
#   ('randomforestregressor', RandomForestRegressor(random_state=42))],
#  'verbose': False,
#  'standardscaler': StandardScaler(),
#  'randomforestregressor': RandomForestRegressor(random_state=42),
#  'standardscaler__copy': True,
#  'standardscaler__with_mean': True,
#  'standardscaler__with_std': True,
#  'randomforestregressor__bootstrap': True,
#  'randomforestregressor__ccp_alpha': 0.0,
#  'randomforestregressor__criterion': 'squared_error',
#  'randomforestregressor__max_depth': None,
#  'randomforestregressor__max_features': 'auto',
#  'randomforestregressor__max_leaf_nodes': None,
#  'randomforestregressor__max_samples': None,
#  'randomforestregressor__min_impurity_decrease': 0.0,
#  'randomforestregressor__min_samples_leaf': 1,
#  'randomforestregressor__min_samples_split': 2,
#  'randomforestregressor__min_weight_fraction_leaf': 0.0,
#  'randomforestregressor__n_estimators': 100,
#  'randomforestregressor__n_jobs': None,
#  'randomforestregressor__oob_score': False,
#  'randomforestregressor__random_state': 42,
#  'randomforestregressor__verbose': 0,
#  'randomforestregressor__warm_start': False}

# %%
#maximum max_depth value of estimators of rf 
est_depth = [estimator.get_depth() for estimator in rf.estimators_]
max(est_depth)
# Out:
# 23

# %%
rf_param_grid = {'randomforestregressor__n_estimators':[25,50,75,100,125,150,175,200],
                 'randomforestregressor__max_depth': range(5, 50, 5)}

# %%
rf_pipe_gs = GridSearchCV(rf_pipe, rf_param_grid, cv =5)
rf_pipe_gs.fit(X_train, y_train);

# %%
print(f'Best parameters: {rf_pipe_gs.best_params_}')
# Out:
# Best parameters: {'randomforestregressor__max_depth': 25, 'randomforestregressor__n_estimators': 50}

# %%
rf_opt = rf_pipe_gs.best_estimator_
rf_opt.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestregressor',
#                  RandomForestRegressor(max_depth=25, n_estimators=50,
#                                        random_state=42))])

# %%
eval_model(rf_opt)
# Out:
#   Metrics Train Score Test Score
# 1     MAE    0.564383   1.736653
# 2     MSE    0.873664   8.975243
# 3    RMSE      0.9347   2.995871
# 4      R2    0.979996   0.798638

# %%
train_test_plot('Optimized Random Forest Model', rf_opt)
# Out:
# (<Figure size 864x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd14cdc98b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd14cc8b730>],
#        dtype=object))

# %% [markdown]
# ## For Bagged Tree

# %%
#parametrs of decision tree model
bt_pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('standardscaler', StandardScaler()),
#   ('baggingregressor', BaggingRegressor(random_state=42))],
#  'verbose': False,
#  'standardscaler': StandardScaler(),
#  'baggingregressor': BaggingRegressor(random_state=42),
#  'standardscaler__copy': True,
#  'standardscaler__with_mean': True,
#  'standardscaler__with_std': True,
#  'baggingregressor__base_estimator': None,
#  'baggingregressor__bootstrap': True,
#  'baggingregressor__bootstrap_features': False,
#  'baggingregressor__max_features': 1.0,
#  'baggingregressor__max_samples': 1.0,
#  'baggingregressor__n_estimators': 10,
#  'baggingregressor__n_jobs': None,
#  'baggingregressor__oob_score': False,
#  'baggingregressor__random_state': 42,
#  'baggingregressor__verbose': 0,
#  'baggingregressor__warm_start': False}

# %%
bt_param_grid = {'baggingregressor__n_estimators':range(10, 80, 10)}

# %%
bt_pipe_gs = GridSearchCV(bt_pipe, bt_param_grid, cv=5)
bt_pipe_gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('baggingregressor',
#                                         BaggingRegressor(random_state=42))]),
#              param_grid={'baggingregressor__n_estimators': range(10, 80, 10)})

# %%
print(f'Best parameters: {bt_pipe_gs.best_params_}')
# Out:
# Best parameters: {'baggingregressor__n_estimators': 60}

# %%
bt_opt = bt_pipe_gs.best_estimator_
bt_opt.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('baggingregressor',
#                  BaggingRegressor(n_estimators=60, random_state=42))])

# %%
eval_model(bt_opt)
# Out:
#   Metrics Train Score Test Score
# 1     MAE    0.550939   1.711683
# 2     MSE    0.831883   8.827774
# 3    RMSE    0.912076   2.971157
# 4      R2    0.980953   0.801947

# %%
train_test_plot('Optimized Bagged Tree Model', bt_opt)
# Out:
# (<Figure size 864x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd1583b0940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd1583815b0>],
#        dtype=object))

# %% [markdown]
# ##Evaluvation of optimized models

# %%
model = ['XG Boost','Random Forest', 'Bagged Tree']
pipe = [xgb_opt, rf_opt, bt_opt]
final_eval_results = pd.DataFrame(columns = ['Model','Train R2', 'Test R2', 'Train RMSE (kcal/mol)', 'Test RMSE (kcal/mol)'])

for i in range(len(model)):
  final_eval_results.loc[i, 'Model'] = model[i]
  final_eval_results.loc[i,'Train R2'], final_eval_results.loc[i,'Test R2'], final_eval_results.loc[i,'Train RMSE (kcal/mol)'], final_eval_results.loc[i,'Test RMSE (kcal/mol)'] = eval_model_final(pipe[i])

# %%
final_eval_results.set_index('Model', inplace = True) 
final_eval_results
# Out:
#                Train R2   Test R2 Train RMSE (kcal/mol) Test RMSE (kcal/mol)
# Model
# XG Boost       0.986399  0.845785              0.770731             2.621787
# Random Forest  0.979996  0.798638                0.9347             2.995871
# Bagged Tree    0.980953  0.801947              0.912076             2.971157

# %% [markdown]
# Acording to the above scores for optimized models, XG Boost regression model is selected as the best ML model since it gained the highest R$^2$ score and lowest train and test RMSE scores.

# %% [markdown]
# # Application of PCA

# %%
print(f'Shape of X_train before PCA: {X_train.shape}')
# Out:
# Shape of X_train before PCA: (654, 6)

# %%
processed_x = scaler.fit_transform(X_train)
print(f'Shape of processed X_train before PCA: {processed_x.shape}')
pca = PCA()
print(f'Shape of processed X_train after PCA: {pca.fit_transform(processed_x).shape}')
# Out:
# Shape of processed X_train before PCA: (654, 6)
# Shape of processed X_train after PCA: (654, 6)

# %%
plt.plot(range(1,7), pca.explained_variance_ratio_, marker = '.')
plt.xticks(ticks = range(1, ), fontsize=8)
plt.xlabel('Principal Component')
plt.ylabel('Proportion of Explained Variance')
# Out:
# Text(0, 0.5, 'Proportion of Explained Variance')

# %%
#define the function for pca model
def pca_model(model):
  pca = PCA(n_components = 0.95)
  model_pca_pipe = make_pipeline(scaler, pca, model)
  model_pca_pipe.fit(X_train, y_train)

  return (model_pca_pipe)

# %%
xgb_pca =pca_model(XGBRegressor(random_state= 42))

#evaluvation of initial xgb with pca
eval_model(xgb_pca)
# Out:
# [22:13:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#   Metrics Train Score Test Score
# 1     MAE    2.118686   3.153822
# 2     MSE   10.170384  24.437216
# 3    RMSE    3.189104   4.943401
# 4      R2    0.767137   0.451745

# %%
bt_pca =pca_model(BaggingRegressor(random_state = 42))

#evaluvation of bt with pca
eval_model(bt_pca)
# Out:
#   Metrics Train Score Test Score
# 1     MAE    1.179539   3.243015
# 2     MSE    3.791804  25.963399
# 3    RMSE    1.947255   5.095429
# 4      R2    0.913182   0.417505

# %%
rf_pca =pca_model(RandomForestRegressor(random_state= 42))

#evaluvation of initial rf with pca
eval_model(rf_pca)
# Out:
#   Metrics Train Score Test Score
# 1     MAE    1.068754   3.031089
# 2     MSE    2.951861  23.977624
# 3    RMSE    1.718098   4.896695
# 4      R2    0.932414   0.462056

# %%
model = ['XG Boost with PCA', 'Bagged Tree with PCA','Random Forest with PCA']
pipe = [xgb_pca, bt_pca, rf_pca]
pca_eval_results = pd.DataFrame(columns = ['Model','Train R2', 'Test R2', 'Train RMSE (kcal/mol)', 'Test RMSE (kcal/mol)'])

for i in range(len(model)):
  pca_eval_results.loc[i, 'Model'] = model[i]
  pca_eval_results.loc[i,'Train R2'], pca_eval_results.loc[i,'Test R2'], pca_eval_results.loc[i,'Train RMSE (kcal/mol)'], pca_eval_results.loc[i,'Test RMSE (kcal/mol)'] = eval_model_final(pipe[i])

# %%
pca_eval_results.set_index('Model', inplace = True) 
pca_eval_results
# Out:
#                         Train R2   Test R2 Train RMSE (kcal/mol)  \
# Model
# XG Boost with PCA       0.767137  0.451745              3.189104
# Bagged Tree with PCA    0.913182  0.417505              1.947255
# Random Forest with PCA  0.932414  0.462056              1.718098
#
#                        Test RMSE (kcal/mol)
# Model
# XG Boost with PCA                  4.943401
# Bagged Tree with PCA               5.095429
# Random Forest with PCA             4.896695

# %% [markdown]
# Application of PCA increased the overfitting even more than the initial models. Therefore, applying PCA is not helpful to enhance the ML models.

# %% [markdown]
# # Deep Learning model

# %%
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Used functions

# %%
# Learning history plotting function
def plot_history(history):
  """Takes a keras model learning history and plots each metric"""
  
  metrics = history.history.keys()
  
  for metric in metrics:
      if not 'val' in metric:
        plt.plot(history.history[f'{metric}'], label=f'{metric}')
        if f'val_{metric}' in metrics:
          plt.plot(history.history[f'val_{metric}'], label=f'val_{metric}')
        plt.legend()
        plt.title(f'{metric}')
        plt.show()

# %%
# Make predictions and evaluate your model
def eval_nn_model(model, X_train_scaled = X_train_scaled, X_test_pca = X_test_scaled):
  train_preds = model.predict(X_train_scaled)
  test_preds = model.predict(X_test_scaled)

  print('training MAE:', mean_absolute_error(y_train, train_preds))
  print('testing MAE:', mean_absolute_error(y_test, test_preds))
  print('\n')
  print('training rmse:', np.sqrt(mean_squared_error(y_train, train_preds)))
  print('testing rmse:', np.sqrt(mean_squared_error(y_test, test_preds)))
  print('\n')
  print('training R2:', r2_score(y_train, train_preds))
  print('testing R2:', r2_score(y_test, test_preds))

# %% [markdown]
# ## Model 1

# %%
input_shape = X_train.shape[1]
input_shape
# Out:
# 6

# %%
model1 = Sequential()

model1.add(Dense(10, input_dim = input_shape, activation = 'relu', name = 'h1'))
model1.add(Dense(10, activation = 'relu', name = 'h2'))
model1.add(Dense(1, activation = 'linear', name = 'output'))

model1.summary()
# Out:
# Model: "sequential_120"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  h1 (Dense)                  (None, 10)                70
#
#  h2 (Dense)                  (None, 10)                110
#
#  output (Dense)              (None, 1)                 11
#
# =================================================================
# Total params: 191
# Trainable params: 191
# Non-trainable params: 0
# _________________________________________________________________

# %%
# this controls the learning rate
opt = tf.keras.optimizers.Adam(learning_rate=0.01)


# compile model with additional metrics
model1.compile(loss = 'mse', optimizer = opt,
               metrics= [metrics.MeanAbsoluteError(),
                        metrics.RootMeanSquaredError()])

# %%
history1 = model1.fit(X_train_scaled, y_train,
                     validation_data = (X_test_scaled, y_test),
                     epochs = 100,
                      batch_size=32)
# Out:
# Epoch 1/100
# 21/21 [==============================] - 1s 10ms/step - loss: 223.4487 - mean_absolute_error: 13.2934 - root_mean_squared_error: 14.9482 - val_loss: 147.0984 - val_mean_absolute_error: 10.0429 - val_root_mean_squared_error: 12.1284
# Epoch 2/100
# 21/21 [==============================] - 0s 4ms/step - loss: 86.8253 - mean_absolute_error: 7.2761 - root_mean_squared_error: 9.3180 - val_loss: 67.3316 - val_mean_absolute_error: 6.0709 - val_root_mean_squared_error: 8.2056
# Epoch 3/100
# 21/21 [==============================] - 0s 4ms/step - loss: 51.0780 - mean_absolute_error: 5.3027 - root_mean_squared_error: 7.1469 - val_loss: 48.1471 - val_mean_absolute_error: 4.7834 - val_root_mean_squared_error: 6.9388
# Epoch 4/100
# 21/21 [==============================] - 0s 4ms/step - loss: 37.0669 - mean_absolute_error: 4.3300 - root_mean_squared_error: 6.0883 - val_loss: 37.9364 - val_mean_absolute_error: 4.1218 - val_root_mean_squared_error: 6.1593
# Epoch 5/100
# 21/21 [==============================] - 0s 4ms/step - loss: 30.9588 - mean_absolute_error: 3.7719 - root_mean_squared_error: 5.5641 - val_loss: 33.7656 - val_mean_absolute_error: 3.7609 - val_root_mean_squared_error: 5.8108
# Epoch 6/100
# 21/21 [==============================] - 0s 5ms/step - loss: 28.5340 - mean_absolute_error: 3.4867 - root_mean_squared_error: 5.3417 - val_loss: 32.0707 - val_mean_absolute_error: 3.5227 - val_root_mean_squared_error: 5.6631
# Epoch 7/100
# 21/21 [==============================] - 0s 4ms/step - loss: 27.0752 - mean_absolute_error: 3.3079 - root_mean_squared_error: 5.2034 - val_loss: 30.2326 - val_mean_absolute_error: 3.4215 - val_root_mean_squared_error: 5.4984
# Epoch 8/100
# 21/21 [==============================] - 0s 4ms/step - loss: 26.0439 - mean_absolute_error: 3.2542 - root_mean_squared_error: 5.1033 - val_loss: 29.1969 - val_mean_absolute_error: 3.2353 - val_root_mean_squared_error: 5.4034
# Epoch 9/100
# 21/21 [==============================] - 0s 3ms/step - loss: 25.3829 - mean_absolute_error: 3.1200 - root_mean_squared_error: 5.0381 - val_loss: 28.8962 - val_mean_absolute_error: 3.2542 - val_root_mean_squared_error: 5.3755
# Epoch 10/100
# 21/21 [==============================] - 0s 4ms/step - loss: 24.6663 - mean_absolute_error: 3.0958 - root_mean_squared_error: 4.9665 - val_loss: 28.0228 - val_mean_absolute_error: 3.1138 - val_root_mean_squared_error: 5.2937
# Epoch 11/100
# 21/21 [==============================] - 0s 4ms/step - loss: 24.5066 - mean_absolute_error: 3.0734 - root_mean_squared_error: 4.9504 - val_loss: 27.9419 - val_mean_absolute_error: 3.1965 - val_root_mean_squared_error: 5.2860
# Epoch 12/100
# 21/21 [==============================] - 0s 4ms/step - loss: 24.4096 - mean_absolute_error: 3.0120 - root_mean_squared_error: 4.9406 - val_loss: 27.3365 - val_mean_absolute_error: 3.0793 - val_root_mean_squared_error: 5.2284
# Epoch 13/100
# 21/21 [==============================] - 0s 4ms/step - loss: 23.9088 - mean_absolute_error: 3.0043 - root_mean_squared_error: 4.8897 - val_loss: 27.2318 - val_mean_absolute_error: 3.0996 - val_root_mean_squared_error: 5.2184
# Epoch 14/100
# 21/21 [==============================] - 0s 5ms/step - loss: 23.7066 - mean_absolute_error: 2.9979 - root_mean_squared_error: 4.8689 - val_loss: 27.1799 - val_mean_absolute_error: 3.0285 - val_root_mean_squared_error: 5.2134
# Epoch 15/100
# 21/21 [==============================] - 0s 4ms/step - loss: 23.6929 - mean_absolute_error: 2.9575 - root_mean_squared_error: 4.8675 - val_loss: 27.2774 - val_mean_absolute_error: 3.0548 - val_root_mean_squared_error: 5.2228
# Epoch 16/100
# 21/21 [==============================] - 0s 4ms/step - loss: 23.5639 - mean_absolute_error: 2.9787 - root_mean_squared_error: 4.8543 - val_loss: 26.9748 - val_mean_absolute_error: 2.9732 - val_root_mean_squared_error: 5.1937
# Epoch 17/100
# 21/21 [==============================] - 0s 4ms/step - loss: 23.5328 - mean_absolute_error: 2.8980 - root_mean_squared_error: 4.8511 - val_loss: 27.2882 - val_mean_absolute_error: 3.1175 - val_root_mean_squared_error: 5.2238
# Epoch 18/100
# 21/21 [==============================] - 0s 4ms/step - loss: 23.5021 - mean_absolute_error: 2.9556 - root_mean_squared_error: 4.8479 - val_loss: 26.9170 - val_mean_absolute_error: 3.0431 - val_root_mean_squared_error: 5.1882
# Epoch 19/100
# 21/21 [==============================] - 0s 4ms/step - loss: 23.1073 - mean_absolute_error: 2.8990 - root_mean_squared_error: 4.8070 - val_loss: 27.7515 - val_mean_absolute_error: 3.1686 - val_root_mean_squared_error: 5.2680
# Epoch 20/100
# 21/21 [==============================] - 0s 4ms/step - loss: 23.7887 - mean_absolute_error: 3.0636 - root_mean_squared_error: 4.8774 - val_loss: 27.0200 - val_mean_absolute_error: 3.0008 - val_root_mean_squared_error: 5.1981
# Epoch 21/100
# 21/21 [==============================] - 0s 4ms/step - loss: 23.4351 - mean_absolute_error: 2.9177 - root_mean_squared_error: 4.8410 - val_loss: 27.0578 - val_mean_absolute_error: 2.9970 - val_root_mean_squared_error: 5.2017
# Epoch 22/100
# 21/21 [==============================] - 0s 4ms/step - loss: 23.1409 - mean_absolute_error: 2.8704 - root_mean_squared_error: 4.8105 - val_loss: 26.7164 - val_mean_absolute_error: 3.1198 - val_root_mean_squared_error: 5.1688
# Epoch 23/100
# 21/21 [==============================] - 0s 3ms/step - loss: 23.3084 - mean_absolute_error: 2.9684 - root_mean_squared_error: 4.8279 - val_loss: 26.5458 - val_mean_absolute_error: 2.9447 - val_root_mean_squared_error: 5.1523
# Epoch 24/100
# 21/21 [==============================] - 0s 4ms/step - loss: 22.9581 - mean_absolute_error: 2.8641 - root_mean_squared_error: 4.7915 - val_loss: 26.5035 - val_mean_absolute_error: 3.0078 - val_root_mean_squared_error: 5.1482
# Epoch 25/100
# 21/21 [==============================] - 0s 4ms/step - loss: 23.4621 - mean_absolute_error: 2.9380 - root_mean_squared_error: 4.8438 - val_loss: 27.8147 - val_mean_absolute_error: 3.1661 - val_root_mean_squared_error: 5.2740
# Epoch 26/100
# 21/21 [==============================] - 0s 3ms/step - loss: 23.2764 - mean_absolute_error: 2.9360 - root_mean_squared_error: 4.8246 - val_loss: 26.8082 - val_mean_absolute_error: 2.9889 - val_root_mean_squared_error: 5.1777
# Epoch 27/100
# 21/21 [==============================] - 0s 5ms/step - loss: 22.8926 - mean_absolute_error: 2.8824 - root_mean_squared_error: 4.7846 - val_loss: 26.3030 - val_mean_absolute_error: 2.9651 - val_root_mean_squared_error: 5.1286
# Epoch 28/100
# 21/21 [==============================] - 0s 4ms/step - loss: 22.8172 - mean_absolute_error: 2.8751 - root_mean_squared_error: 4.7767 - val_loss: 26.2443 - val_mean_absolute_error: 2.9641 - val_root_mean_squared_error: 5.1229
# Epoch 29/100
# 21/21 [==============================] - 0s 4ms/step - loss: 22.7496 - mean_absolute_error: 2.8707 - root_mean_squared_error: 4.7697 - val_loss: 26.9314 - val_mean_absolute_error: 2.9345 - val_root_mean_squared_error: 5.1895
# Epoch 30/100
# 21/21 [==============================] - 0s 3ms/step - loss: 23.1406 - mean_absolute_error: 2.8637 - root_mean_squared_error: 4.8105 - val_loss: 26.0736 - val_mean_absolute_error: 2.9855 - val_root_mean_squared_error: 5.1062
# Epoch 31/100
# 21/21 [==============================] - 0s 4ms/step - loss: 22.5739 - mean_absolute_error: 2.8263 - root_mean_squared_error: 4.7512 - val_loss: 26.1019 - val_mean_absolute_error: 2.9457 - val_root_mean_squared_error: 5.1090
# Epoch 32/100
# 21/21 [==============================] - 0s 3ms/step - loss: 22.3278 - mean_absolute_error: 2.8542 - root_mean_squared_error: 4.7252 - val_loss: 26.3455 - val_mean_absolute_error: 2.8888 - val_root_mean_squared_error: 5.1328
# Epoch 33/100
# Epoch 46/100
# 21/21 [==============================] - 0s 3ms/step - loss: 21.9684 - mean_absolute_error: 2.7247 - root_mean_squared_error: 4.6870 - val_loss: 26.2249 - val_mean_absolute_error: 3.0616 - val_root_mean_squared_error: 5.1210
# Epoch 47/100
# 21/21 [==============================] - 0s 4ms/step - loss: 21.6306 - mean_absolute_error: 2.7561 - root_mean_squared_error: 4.6509 - val_loss: 26.3429 - val_mean_absolute_error: 2.8814 - val_root_mean_squared_error: 5.1325
# Epoch 48/100
# 21/21 [==============================] - 0s 3ms/step - loss: 21.7983 - mean_absolute_error: 2.7601 - root_mean_squared_error: 4.6689 - val_loss: 25.5882 - val_mean_absolute_error: 2.9319 - val_root_mean_squared_error: 5.0585
# Epoch 49/100
# 21/21 [==============================] - 0s 4ms/step - loss: 21.3935 - mean_absolute_error: 2.7060 - root_mean_squared_error: 4.6253 - val_loss: 25.5706 - val_mean_absolute_error: 2.8808 - val_root_mean_squared_error: 5.0567
# Epoch 50/100
# 21/21 [==============================] - 0s 3ms/step - loss: 21.4739 - mean_absolute_error: 2.7122 - root_mean_squared_error: 4.6340 - val_loss: 26.0783 - val_mean_absolute_error: 2.9328 - val_root_mean_squared_error: 5.1067
# Epoch 51/100
# 21/21 [==============================] - 0s 3ms/step - loss: 21.3476 - mean_absolute_error: 2.7296 - root_mean_squared_error: 4.6203 - val_loss: 25.4317 - val_mean_absolute_error: 2.8940 - val_root_mean_squared_error: 5.0430
# Epoch 52/100
# 21/21 [==============================] - 0s 4ms/step - loss: 21.3500 - mean_absolute_error: 2.6667 - root_mean_squared_error: 4.6206 - val_loss: 25.8222 - val_mean_absolute_error: 2.8966 - val_root_mean_squared_error: 5.0816
# Epoch 53/100
# 21/21 [==============================] - 0s 4ms/step - loss: 21.1386 - mean_absolute_error: 2.6839 - root_mean_squared_error: 4.5977 - val_loss: 26.3154 - val_mean_absolute_error: 3.0721 - val_root_mean_squared_error: 5.1299
# Epoch 54/100
# 21/21 [==============================] - 0s 4ms/step - loss: 22.2486 - mean_absolute_error: 2.8403 - root_mean_squared_error: 4.7168 - val_loss: 26.1035 - val_mean_absolute_error: 2.9380 - val_root_mean_squared_error: 5.1092
# Epoch 55/100
# 21/21 [==============================] - 0s 4ms/step - loss: 22.0930 - mean_absolute_error: 2.8231 - root_mean_squared_error: 4.7003 - val_loss: 25.5348 - val_mean_absolute_error: 2.8110 - val_root_mean_squared_error: 5.0532
# Epoch 56/100
# 21/21 [==============================] - 0s 3ms/step - loss: 21.3716 - mean_absolute_error: 2.7020 - root_mean_squared_error: 4.6229 - val_loss: 26.2533 - val_mean_absolute_error: 3.0204 - val_root_mean_squared_error: 5.1238
# Epoch 57/100
# 21/21 [==============================] - 0s 3ms/step - loss: 21.5121 - mean_absolute_error: 2.7194 - root_mean_squared_error: 4.6381 - val_loss: 25.3770 - val_mean_absolute_error: 2.9339 - val_root_mean_squared_error: 5.0376
# Epoch 58/100
# Epoch 71/100
# 21/21 [==============================] - 0s 4ms/step - loss: 21.3379 - mean_absolute_error: 2.6806 - root_mean_squared_error: 4.6193 - val_loss: 25.8452 - val_mean_absolute_error: 2.8803 - val_root_mean_squared_error: 5.0838
# Epoch 72/100
# 21/21 [==============================] - 0s 4ms/step - loss: 21.4727 - mean_absolute_error: 2.7232 - root_mean_squared_error: 4.6339 - val_loss: 25.8338 - val_mean_absolute_error: 2.7946 - val_root_mean_squared_error: 5.0827
# Epoch 73/100
# 21/21 [==============================] - 0s 4ms/step - loss: 21.5131 - mean_absolute_error: 2.7323 - root_mean_squared_error: 4.6382 - val_loss: 25.0938 - val_mean_absolute_error: 2.8143 - val_root_mean_squared_error: 5.0094
# Epoch 74/100
# 21/21 [==============================] - 0s 4ms/step - loss: 21.1527 - mean_absolute_error: 2.6379 - root_mean_squared_error: 4.5992 - val_loss: 25.2657 - val_mean_absolute_error: 2.9536 - val_root_mean_squared_error: 5.0265
# Epoch 75/100
# 21/21 [==============================] - 0s 4ms/step - loss: 20.8733 - mean_absolute_error: 2.6644 - root_mean_squared_error: 4.5687 - val_loss: 25.6577 - val_mean_absolute_error: 2.7961 - val_root_mean_squared_error: 5.0653
# Epoch 76/100
# 21/21 [==============================] - 0s 4ms/step - loss: 21.1059 - mean_absolute_error: 2.6277 - root_mean_squared_error: 4.5941 - val_loss: 25.1237 - val_mean_absolute_error: 2.8594 - val_root_mean_squared_error: 5.0124
# Epoch 77/100
# 21/21 [==============================] - 0s 3ms/step - loss: 21.0101 - mean_absolute_error: 2.6285 - root_mean_squared_error: 4.5837 - val_loss: 25.3436 - val_mean_absolute_error: 2.8949 - val_root_mean_squared_error: 5.0342
# Epoch 78/100
# 21/21 [==============================] - 0s 3ms/step - loss: 21.0728 - mean_absolute_error: 2.6495 - root_mean_squared_error: 4.5905 - val_loss: 25.0839 - val_mean_absolute_error: 2.8937 - val_root_mean_squared_error: 5.0084
# Epoch 79/100
# 21/21 [==============================] - 0s 3ms/step - loss: 21.2699 - mean_absolute_error: 2.7396 - root_mean_squared_error: 4.6119 - val_loss: 25.5645 - val_mean_absolute_error: 2.8018 - val_root_mean_squared_error: 5.0561
# Epoch 80/100
# 21/21 [==============================] - 0s 4ms/step - loss: 21.3107 - mean_absolute_error: 2.6916 - root_mean_squared_error: 4.6164 - val_loss: 25.1034 - val_mean_absolute_error: 2.9278 - val_root_mean_squared_error: 5.0103
# Epoch 81/100
# 21/21 [==============================] - 0s 4ms/step - loss: 21.2510 - mean_absolute_error: 2.7048 - root_mean_squared_error: 4.6099 - val_loss: 25.0872 - val_mean_absolute_error: 2.8640 - val_root_mean_squared_error: 5.0087
# Epoch 82/100
# 21/21 [==============================] - 0s 4ms/step - loss: 21.1904 - mean_absolute_error: 2.6787 - root_mean_squared_error: 4.6033 - val_loss: 25.7667 - val_mean_absolute_error: 2.7937 - val_root_mean_squared_error: 5.0761
# Epoch 83/100
# 21/21 [==============================] - 0s 4ms/step - loss: 21.3132 - mean_absolute_error: 2.6642 - root_mean_squared_error: 4.6166 - val_loss: 25.1563 - val_mean_absolute_error: 2.9537 - val_root_mean_squared_error: 5.0156
# Epoch 84/100
# 21/21 [==============================] - 0s 4ms/step - loss: 21.3490 - mean_absolute_error: 2.7174 - root_mean_squared_error: 4.6205 - val_loss: 25.2685 - val_mean_absolute_error: 2.8742 - val_root_mean_squared_error: 5.0268
# Epoch 85/100
# 21/21 [==============================] - 0s 3ms/step - loss: 21.0258 - mean_absolute_error: 2.6286 - root_mean_squared_error: 4.5854 - val_loss: 25.1328 - val_mean_absolute_error: 2.9686 - val_root_mean_squared_error: 5.0133
# Epoch 86/100
# 21/21 [==============================] - 0s 4ms/step - loss: 21.0672 - mean_absolute_error: 2.6468 - root_mean_squared_error: 4.5899 - val_loss: 25.1490 - val_mean_absolute_error: 2.7952 - val_root_mean_squared_error: 5.0149
# Epoch 87/100
# 21/21 [==============================] - 0s 5ms/step - loss: 20.8311 - mean_absolute_error: 2.6279 - root_mean_squared_error: 4.5641 - val_loss: 25.0896 - val_mean_absolute_error: 2.9158 - val_root_mean_squared_error: 5.0089
# Epoch 88/100
# 21/21 [==============================] - 0s 4ms/step - loss: 21.4622 - mean_absolute_error: 2.6927 - root_mean_squared_error: 4.6327 - val_loss: 25.9051 - val_mean_absolute_error: 3.0757 - val_root_mean_squared_error: 5.0897
# Epoch 89/100
# 21/21 [==============================] - 0s 3ms/step - loss: 21.3392 - mean_absolute_error: 2.6765 - root_mean_squared_error: 4.6194 - val_loss: 25.1435 - val_mean_absolute_error: 2.8820 - val_root_mean_squared_error: 5.0143
# Epoch 90/100
# 21/21 [==============================] - 0s 4ms/step - loss: 20.8851 - mean_absolute_error: 2.6366 - root_mean_squared_error: 4.5700 - val_loss: 25.0612 - val_mean_absolute_error: 2.9138 - val_root_mean_squared_error: 5.0061
# Epoch 91/100
# 21/21 [==============================] - 0s 3ms/step - loss: 20.7238 - mean_absolute_error: 2.6259 - root_mean_squared_error: 4.5523 - val_loss: 25.5302 - val_mean_absolute_error: 2.8634 - val_root_mean_squared_error: 5.0527
# Epoch 92/100
# 21/21 [==============================] - 0s 3ms/step - loss: 20.9095 - mean_absolute_error: 2.5948 - root_mean_squared_error: 4.5727 - val_loss: 25.6127 - val_mean_absolute_error: 3.1331 - val_root_mean_squared_error: 5.0609
# Epoch 93/100
# 21/21 [==============================] - 0s 4ms/step - loss: 21.3859 - mean_absolute_error: 2.6449 - root_mean_squared_error: 4.6245 - val_loss: 24.8584 - val_mean_absolute_error: 2.9678 - val_root_mean_squared_error: 4.9858
# Epoch 94/100
# 21/21 [==============================] - 0s 4ms/step - loss: 20.8809 - mean_absolute_error: 2.6567 - root_mean_squared_error: 4.5696 - val_loss: 25.1427 - val_mean_absolute_error: 2.8694 - val_root_mean_squared_error: 5.0143
# Epoch 95/100
# 21/21 [==============================] - 0s 4ms/step - loss: 21.1886 - mean_absolute_error: 2.6154 - root_mean_squared_error: 4.6031 - val_loss: 25.1973 - val_mean_absolute_error: 2.8261 - val_root_mean_squared_error: 5.0197
# Epoch 96/100
# 21/21 [==============================] - 0s 4ms/step - loss: 21.0199 - mean_absolute_error: 2.7360 - root_mean_squared_error: 4.5848 - val_loss: 25.4664 - val_mean_absolute_error: 2.7862 - val_root_mean_squared_error: 5.0464
# Epoch 97/100
# 21/21 [==============================] - 0s 4ms/step - loss: 21.3777 - mean_absolute_error: 2.6406 - root_mean_squared_error: 4.6236 - val_loss: 25.3875 - val_mean_absolute_error: 2.9960 - val_root_mean_squared_error: 5.0386
# Epoch 98/100
# 21/21 [==============================] - 0s 4ms/step - loss: 20.7052 - mean_absolute_error: 2.6398 - root_mean_squared_error: 4.5503 - val_loss: 25.6411 - val_mean_absolute_error: 2.8166 - val_root_mean_squared_error: 5.0637
# Epoch 99/100
# 21/21 [==============================] - 0s 4ms/step - loss: 21.1444 - mean_absolute_error: 2.6440 - root_mean_squared_error: 4.5983 - val_loss: 25.1879 - val_mean_absolute_error: 3.0097 - val_root_mean_squared_error: 5.0188
# Epoch 100/100
# 21/21 [==============================] - 0s 4ms/step - loss: 20.9676 - mean_absolute_error: 2.6587 - root_mean_squared_error: 4.5790 - val_loss: 25.9091 - val_mean_absolute_error: 2.9308 - val_root_mean_squared_error: 5.0901

# %%
plot_history(history1)

# %%
eval_nn_model(model1)
# Out:
# 21/21 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# training MAE: 2.709289225230002
# testing MAE: 2.930801191382574
#
#
# training rmse: 4.609922277619118
# testing rmse: 5.09010180637905
#
#
# training R2: 0.5134245904414971
# testing R2: 0.41872232895665484

# %%
train_test_plot('Neural Networl Model 1', model1, X_train=X_train_scaled, y_train=y_train, X_test=X_test_scaled , y_test= y_test)
# Out:
# 21/21 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 3ms/step
# 7/7 [==============================] - 0s 5ms/step
# (<Figure size 864x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd1592b4a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd1548c9340>],
#        dtype=object))

# %% [markdown]
# - By looking at the above plots, model1 is too simple or trained for too few epochs to predict a dataset well. As the next step, I will increase the complexity of the model.
# - According to the calculated scores, training scores are better than the testing scores which implies the overfitting.
# - So I just give a try by making the model much complicated by increasing the number of nodes and epoches.
# - And also use the early stopping method to restrict over doing the epochs.

# %% [markdown]
# ## Model 2

# %%
input_shape = X_train.shape[1]
input_shape
# Out:
# 6

# %%
model2 = Sequential()

model2.add(Dense(20, input_dim = input_shape, activation = 'relu', name = 'h1'))
model2.add(Dense(20, activation = 'relu', name = 'h2'))
model2.add(Dense(1, activation = 'linear', name = 'output'))

model2.summary()
# Out:
# Model: "sequential_121"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  h1 (Dense)                  (None, 20)                140
#
#  h2 (Dense)                  (None, 20)                420
#
#  output (Dense)              (None, 1)                 21
#
# =================================================================
# Total params: 581
# Trainable params: 581
# Non-trainable params: 0
# _________________________________________________________________

# %%
# this controls the learning rate
opt = tf.keras.optimizers.Adam(learning_rate=0.01)


# compile model with additional metrics
model2.compile(loss = 'mse', optimizer = opt,
               metrics= [metrics.MeanAbsoluteError(),
                        metrics.RootMeanSquaredError()])

# %%
early_stopping = EarlyStopping(patience= 10)

# %%
from xgboost.training import callback
history2 = model2.fit(X_train_scaled, y_train,
                     validation_data = (X_test_scaled, y_test),
                     epochs = 200,
                      batch_size=32,
                      callbacks = [early_stopping])
# Out:
# Epoch 1/200
# 21/21 [==============================] - 1s 12ms/step - loss: 198.3718 - mean_absolute_error: 12.0200 - root_mean_squared_error: 14.0845 - val_loss: 88.4327 - val_mean_absolute_error: 7.3636 - val_root_mean_squared_error: 9.4039
# Epoch 2/200
# 21/21 [==============================] - 0s 4ms/step - loss: 59.8129 - mean_absolute_error: 5.8294 - root_mean_squared_error: 7.7339 - val_loss: 51.5227 - val_mean_absolute_error: 4.9782 - val_root_mean_squared_error: 7.1779
# Epoch 3/200
# 21/21 [==============================] - 0s 4ms/step - loss: 38.3514 - mean_absolute_error: 4.3587 - root_mean_squared_error: 6.1929 - val_loss: 40.1286 - val_mean_absolute_error: 4.2478 - val_root_mean_squared_error: 6.3347
# Epoch 4/200
# 21/21 [==============================] - 0s 4ms/step - loss: 31.5117 - mean_absolute_error: 3.7736 - root_mean_squared_error: 5.6135 - val_loss: 34.7478 - val_mean_absolute_error: 3.6634 - val_root_mean_squared_error: 5.8947
# Epoch 5/200
# 21/21 [==============================] - 0s 3ms/step - loss: 28.1958 - mean_absolute_error: 3.4264 - root_mean_squared_error: 5.3100 - val_loss: 31.6731 - val_mean_absolute_error: 3.4579 - val_root_mean_squared_error: 5.6279
# Epoch 6/200
# 21/21 [==============================] - 0s 4ms/step - loss: 25.9636 - mean_absolute_error: 3.2105 - root_mean_squared_error: 5.0954 - val_loss: 29.4215 - val_mean_absolute_error: 3.2427 - val_root_mean_squared_error: 5.4242
# Epoch 7/200
# 21/21 [==============================] - 0s 4ms/step - loss: 24.9077 - mean_absolute_error: 3.0617 - root_mean_squared_error: 4.9908 - val_loss: 28.0065 - val_mean_absolute_error: 3.3063 - val_root_mean_squared_error: 5.2921
# Epoch 8/200
# 21/21 [==============================] - 0s 4ms/step - loss: 24.2392 - mean_absolute_error: 3.0378 - root_mean_squared_error: 4.9233 - val_loss: 26.3141 - val_mean_absolute_error: 3.0765 - val_root_mean_squared_error: 5.1297
# Epoch 9/200
# 21/21 [==============================] - 0s 4ms/step - loss: 23.0111 - mean_absolute_error: 2.9365 - root_mean_squared_error: 4.7970 - val_loss: 26.8961 - val_mean_absolute_error: 3.1479 - val_root_mean_squared_error: 5.1861
# Epoch 10/200
# 21/21 [==============================] - 0s 4ms/step - loss: 22.5903 - mean_absolute_error: 2.8750 - root_mean_squared_error: 4.7529 - val_loss: 25.3394 - val_mean_absolute_error: 2.9674 - val_root_mean_squared_error: 5.0338
# Epoch 11/200
# 21/21 [==============================] - 0s 4ms/step - loss: 21.4097 - mean_absolute_error: 2.8007 - root_mean_squared_error: 4.6271 - val_loss: 24.5180 - val_mean_absolute_error: 2.8915 - val_root_mean_squared_error: 4.9516
# Epoch 12/200
# 21/21 [==============================] - 0s 4ms/step - loss: 11.4568 - mean_absolute_error: 2.2526 - root_mean_squared_error: 3.3848 - val_loss: 10.1994 - val_mean_absolute_error: 2.2683 - val_root_mean_squared_error: 3.1937
# Epoch 138/200
# 21/21 [==============================] - 0s 3ms/step - loss: 10.5356 - mean_absolute_error: 2.0853 - root_mean_squared_error: 3.2459 - val_loss: 9.7937 - val_mean_absolute_error: 2.2058 - val_root_mean_squared_error: 3.1295
# Epoch 139/200
# 21/21 [==============================] - 0s 4ms/step - loss: 11.1574 - mean_absolute_error: 2.1744 - root_mean_squared_error: 3.3403 - val_loss: 12.2190 - val_mean_absolute_error: 2.3816 - val_root_mean_squared_error: 3.4956
# Epoch 140/200
# 21/21 [==============================] - 0s 4ms/step - loss: 10.5329 - mean_absolute_error: 2.0929 - root_mean_squared_error: 3.2454 - val_loss: 11.2081 - val_mean_absolute_error: 2.5289 - val_root_mean_squared_error: 3.3479
# Epoch 141/200
# 21/21 [==============================] - 0s 4ms/step - loss: 10.9462 - mean_absolute_error: 2.1656 - root_mean_squared_error: 3.3085 - val_loss: 10.7340 - val_mean_absolute_error: 2.2395 - val_root_mean_squared_error: 3.2763
# Epoch 142/200
# 21/21 [==============================] - 0s 3ms/step - loss: 10.4395 - mean_absolute_error: 2.0490 - root_mean_squared_error: 3.2310 - val_loss: 10.2104 - val_mean_absolute_error: 2.3068 - val_root_mean_squared_error: 3.1954
# Epoch 143/200
# 21/21 [==============================] - 0s 3ms/step - loss: 10.0744 - mean_absolute_error: 2.0055 - root_mean_squared_error: 3.1740 - val_loss: 11.4235 - val_mean_absolute_error: 2.4224 - val_root_mean_squared_error: 3.3799
# Epoch 144/200
# 21/21 [==============================] - 0s 4ms/step - loss: 10.7525 - mean_absolute_error: 2.1275 - root_mean_squared_error: 3.2791 - val_loss: 11.0891 - val_mean_absolute_error: 2.2995 - val_root_mean_squared_error: 3.3300
# Epoch 145/200
# 21/21 [==============================] - 0s 4ms/step - loss: 10.2958 - mean_absolute_error: 2.0900 - root_mean_squared_error: 3.2087 - val_loss: 10.8701 - val_mean_absolute_error: 2.2863 - val_root_mean_squared_error: 3.2970
# Epoch 146/200
# 21/21 [==============================] - 0s 5ms/step - loss: 10.5949 - mean_absolute_error: 2.1168 - root_mean_squared_error: 3.2550 - val_loss: 11.0096 - val_mean_absolute_error: 2.2913 - val_root_mean_squared_error: 3.3181
# Epoch 147/200
# 21/21 [==============================] - 0s 4ms/step - loss: 10.3944 - mean_absolute_error: 2.0796 - root_mean_squared_error: 3.2240 - val_loss: 11.5010 - val_mean_absolute_error: 2.4068 - val_root_mean_squared_error: 3.3913
# Epoch 148/200
# 21/21 [==============================] - 0s 4ms/step - loss: 11.0103 - mean_absolute_error: 2.1910 - root_mean_squared_error: 3.3182 - val_loss: 10.1647 - val_mean_absolute_error: 2.1756 - val_root_mean_squared_error: 3.1882

# %%
plot_history(history2)

# %%
eval_nn_model(model2)
# Out:
# 21/21 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# training MAE: 2.0139390863164226
# testing MAE: 2.175603421359757
#
#
# training rmse: 3.1612322889435487
# testing rmse: 3.1882201386652698
#
#
# training R2: 0.7711895956509095
# testing R2: 0.7719514556108411

# %%
train_test_plot('Neural Networl Model 2', model2, X_train=X_train_scaled, y_train=y_train, X_test=X_test_scaled , y_test= y_test)
# Out:
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# (<Figure size 864x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd159c011c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd1590f28b0>],
#        dtype=object))

# %% [markdown]
# - In this model, the number of nodes increased from 10 to 20 and add early stopping method with the patience level of 10.
# - According to R$^2$ scores, testing score is higher than the training score which is very good.
# - But in MAE and RMSE scores, training score is slightly higher than the testing score.
# - So far, model 2 is the best model to predict BDE with the minimum overfitting.

# %% [markdown]
# - Here, I'm going to introduce model 3 by doing further modifications to model 2  to have better predictions.
# - In model 3;
#     - increase number of layers
#     - increase number of nodes and applying "Dropout" to turn off some nodes during the training process to choose the correct number of nodes. This is a remedy for overfitting.
#     - As another solution for overfitting, L1 and L2 regularization is used

# %% [markdown]
# ## Model 3

# %%
input_shape = X_train.shape[1]
input_shape
# Out:
# 6

# %%
model3 = Sequential()

model3.add(Dense(50, input_dim = input_shape, activation = 'relu', name = 'h1', 
                 kernel_regularizer = regularizers.l1_l2(l1 = 1e-9, l2 = 1e-7),
                 bias_regularizer = regularizers.l2(1e-7),
                 activity_regularizer = regularizers.l2(1e-7) ))
model3.add(Dropout(0.2))
model3.add(Dense(50, activation = 'relu', name = 'h2', 
                 kernel_regularizer = regularizers.l1_l2(l1 = 1e-9, l2 = 1e-7),
                 bias_regularizer = regularizers.l2(1e-7),
                 activity_regularizer = regularizers.l2(1e-7) ))
model3.add(Dropout(0.2))
model3.add(Dense(50, activation = 'relu', name = 'h3', 
                 kernel_regularizer = regularizers.l1_l2(l1 = 1e-9, l2 = 1e-7),
                 bias_regularizer = regularizers.l2(1e-7),
                 activity_regularizer = regularizers.l2(1e-7) ))
model3.add(Dropout(0.2))

model3.add(Dense(1, activation = 'linear', name = 'output'))

model3.summary()
# Out:
# Model: "sequential_128"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  h1 (Dense)                  (None, 50)                350
#
#  dropout_59 (Dropout)        (None, 50)                0
#
#  h2 (Dense)                  (None, 50)                2550
#
#  dropout_60 (Dropout)        (None, 50)                0
#
#  h3 (Dense)                  (None, 50)                2550
#
#  dropout_61 (Dropout)        (None, 50)                0
#
#  output (Dense)              (None, 1)                 51
#
# =================================================================
# Total params: 5,501
# Trainable params: 5,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
# this controls the learning rate
opt = tf.keras.optimizers.Adam(learning_rate=0.01)


# compile model with additional metrics
model3.compile(loss = 'mse', optimizer = opt,
               metrics= [metrics.MeanAbsoluteError(),
                        metrics.RootMeanSquaredError()])

# %%
early_stopping = EarlyStopping(patience= 10)

# %%
from xgboost.training import callback
history3 = model3.fit(X_train_scaled, y_train,
                     validation_data = (X_test_scaled, y_test),
                     epochs = 500,
                      batch_size=32,
                      callbacks = [early_stopping])
# Out:
# Epoch 1/500
# 21/21 [==============================] - 1s 17ms/step - loss: 117.2113 - mean_absolute_error: 8.6217 - root_mean_squared_error: 10.8264 - val_loss: 61.3148 - val_mean_absolute_error: 5.6434 - val_root_mean_squared_error: 7.8304
# Epoch 2/500
# 21/21 [==============================] - 0s 4ms/step - loss: 48.4128 - mean_absolute_error: 5.0122 - root_mean_squared_error: 6.9579 - val_loss: 35.9293 - val_mean_absolute_error: 3.7752 - val_root_mean_squared_error: 5.9941
# Epoch 3/500
# 21/21 [==============================] - 0s 5ms/step - loss: 38.7632 - mean_absolute_error: 4.2732 - root_mean_squared_error: 6.2260 - val_loss: 30.4396 - val_mean_absolute_error: 3.2644 - val_root_mean_squared_error: 5.5172
# Epoch 4/500
# 21/21 [==============================] - 0s 4ms/step - loss: 33.5127 - mean_absolute_error: 3.8521 - root_mean_squared_error: 5.7890 - val_loss: 27.6243 - val_mean_absolute_error: 3.0986 - val_root_mean_squared_error: 5.2559
# Epoch 5/500
# 21/21 [==============================] - 0s 7ms/step - loss: 32.9001 - mean_absolute_error: 3.8867 - root_mean_squared_error: 5.7359 - val_loss: 29.0331 - val_mean_absolute_error: 3.1963 - val_root_mean_squared_error: 5.3882
# Epoch 6/500
# 21/21 [==============================] - 0s 8ms/step - loss: 31.2157 - mean_absolute_error: 3.6678 - root_mean_squared_error: 5.5871 - val_loss: 26.5349 - val_mean_absolute_error: 2.8487 - val_root_mean_squared_error: 5.1512
# Epoch 7/500
# 21/21 [==============================] - 0s 7ms/step - loss: 30.2355 - mean_absolute_error: 3.6474 - root_mean_squared_error: 5.4987 - val_loss: 26.8107 - val_mean_absolute_error: 3.1852 - val_root_mean_squared_error: 5.1779
# Epoch 8/500
# 21/21 [==============================] - 0s 6ms/step - loss: 29.4012 - mean_absolute_error: 3.5995 - root_mean_squared_error: 5.4223 - val_loss: 25.7959 - val_mean_absolute_error: 3.1175 - val_root_mean_squared_error: 5.0790
# Epoch 9/500
# 21/21 [==============================] - 0s 7ms/step - loss: 29.9819 - mean_absolute_error: 3.6518 - root_mean_squared_error: 5.4756 - val_loss: 25.8961 - val_mean_absolute_error: 3.0876 - val_root_mean_squared_error: 5.0888
# Epoch 10/500
# 21/21 [==============================] - 0s 9ms/step - loss: 27.7227 - mean_absolute_error: 3.6312 - root_mean_squared_error: 5.2652 - val_loss: 27.2695 - val_mean_absolute_error: 3.0313 - val_root_mean_squared_error: 5.2220
# Epoch 11/500
# 21/21 [==============================] - 0s 6ms/step - loss: 28.1174 - mean_absolute_error: 3.4826 - root_mean_squared_error: 5.3026 - val_loss: 24.4207 - val_mean_absolute_error: 2.8445 - val_root_mean_squared_error: 4.9417
# Epoch 12/500
# 21/21 [==============================] - 0s 7ms/step - loss: 25.9484 - mean_absolute_error: 3.3601 - root_mean_squared_error: 5.0940 - val_loss: 24.0222 - val_mean_absolute_error: 2.9167 - val_root_mean_squared_error: 4.9012
# Epoch 13/500
# Epoch 51/500
# 21/21 [==============================] - 0s 4ms/step - loss: 23.7525 - mean_absolute_error: 3.1792 - root_mean_squared_error: 4.8736 - val_loss: 20.1924 - val_mean_absolute_error: 2.8829 - val_root_mean_squared_error: 4.4936
# Epoch 52/500
# 21/21 [==============================] - 0s 4ms/step - loss: 21.2235 - mean_absolute_error: 3.0849 - root_mean_squared_error: 4.6069 - val_loss: 19.5270 - val_mean_absolute_error: 2.8113 - val_root_mean_squared_error: 4.4189
# Epoch 53/500
# 21/21 [==============================] - 0s 4ms/step - loss: 21.8322 - mean_absolute_error: 3.1808 - root_mean_squared_error: 4.6725 - val_loss: 21.9046 - val_mean_absolute_error: 3.0828 - val_root_mean_squared_error: 4.6802

# %%
plot_history(history3)

# %%
eval_nn_model(model3)
# Out:
# 21/21 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 2ms/step
# training MAE: 2.7161707273895503
# testing MAE: 3.082845541293876
#
#
# training rmse: 4.141481774981049
# testing rmse: 4.680231658093006
#
#
# training R2: 0.6072877403073511
# testing R2: 0.5085657702720122

# %%
train_test_plot('Neural Networl Model 3', model3, X_train=X_train_scaled, y_train=y_train, X_test=X_test_scaled , y_test= y_test)
# Out:
# 21/21 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 4ms/step
# 7/7 [==============================] - 0s 3ms/step
# 7/7 [==============================] - 0s 3ms/step
# (<Figure size 864x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd158ee35b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd15d7f5490>],
#        dtype=object))

# %% [markdown]
# - According to the scores, model 3 is still suffering from the overfitting and the performence has decreased comparative to model 2.

# %% [markdown]
# ## Summary of NN models

# %%
models = [model1, model2, model3]
nn_scores = pd.DataFrame()

for i,mod in enumerate(models):
  test_pred = mod.predict(X_test_scaled)
  train_pred = mod.predict(X_train_scaled)
  nn_scores.loc[i, 'Model'] = f'Model{i+1}'
  nn_scores.loc[i, 'Train R2'] = round(r2_score(y_train, train_pred),6)
  nn_scores.loc[i, 'Test R2'] = round(r2_score(y_test, test_pred),6) 
  nn_scores.loc[i, 'Train RMSE (kcal/mol)'] = round(np.sqrt(mean_squared_error(y_train, train_pred)),6)
  nn_scores.loc[i, 'Test RMSE (kcal/mol)'] = round(np.sqrt(mean_squared_error(y_test, test_pred)),6)
# Out:
# 7/7 [==============================] - 0s 4ms/step
# 21/21 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step

# %%
nn_scores.set_index('Model', inplace = True)

# %%
nn_scores
# Out:
#         Train R2   Test R2  Train RMSE (kcal/mol)  Test RMSE (kcal/mol)
# Model
# Model1  0.513425  0.418722               4.609922              5.090102
# Model2  0.771190  0.771951               3.161232              3.188220
# Model3  0.607288  0.508566               4.141482              4.680232

# %% [markdown]
# Out of all ML models and NN models, model 2 is selected as best model because it showed the best performce (R$^2$ scors) with minimum overfitting.
