# %% [markdown]
# <a href="https://colab.research.google.com/github/sheha919/Cobaltocenium_project/blob/main/ml_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D



from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn import set_config
set_config(display='diagram')
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA

# Keras
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras import metrics
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping

import shap
from lime.lime_tabular import LimeTabularExplainer

## Customization Options
plt.style.use(('ggplot','tableau-colorblind10'))
sns.set_context(context='notebook', font_scale= 1.2)
plt.rcParams['savefig.transparent'] = False
plt.rcParams['savefig.bbox'] = 'tight'
plt.rcParams['figure.facecolor']='white'
# Out:
# C:\Users\sheha\anaconda3\envs\dojo-env\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
df=pd.read_excel('cobaltocenium_data_new.xlsx')
df.head()
# Out:
#    Unnamed: 0                           Name  CoCp2 energy CoCp name  \
# 0           0   Co(Cp-N(CH₃)₂)(Cp-N(CH₃)₂)OH  -2113.503825   N(CH₃)₂
# 1           1      Co(Cp-N(CH₃)₂)(Cp-OCH₃)OH  -2094.048389      OCH₃
# 2           2  Co(Cp-N(CH₃)₂)(Cp-O(CO)CH₃)OH  -2207.402596  O(CO)CH₃
# 3           3   Co(Cp-N(CH₃)₂)(Cp-P(CH₃)₂)OH  -2400.122408   P(CH₃)₂
# 4           4    Co(Cp-N(CH₃)₂)(Cp-S(CH₃))OH  -2417.026291    S(CH₃)
#
#    CoCp energy  Cp name   Cp energy        BDE  Dipole moment  \
# 0 -1785.987408  N(CH₃)₂ -327.488954  17.233174        15.5954
# 1 -1766.531474  N(CH₃)₂ -327.488954  17.545539        14.9760
# 2 -1879.885018  N(CH₃)₂ -327.488954  17.961810        18.7135
# 3 -2072.607246  N(CH₃)₂ -327.488954  16.445457        19.9044
# 4 -2089.514536  N(CH₃)₂ -327.488954  14.308038        14.9101
#
#    CoCp2 HOMO energy  ...  CoCp H charge  Cp H charge  CoCp proton afinity  \
# 0            -0.1803  ...       0.011840      0.01184            -0.591092
# 1            -0.1867  ...      -0.015190      0.01184            -0.585828
# 2            -0.1849  ...       0.071736      0.01184            -0.522421
# 3            -0.1862  ...      -0.059590      0.01184            -0.565904
# 4            -0.1868  ...       0.019722      0.01184            -0.564128
#
#    Cp proton afinity  proton afinity  CoCp polarizability  Cp polarizability  \
# 0          -0.591092       -0.591092             27.53932           27.53932
# 1          -0.591092       -0.588460             18.01558           27.53932
# 2          -0.591092       -0.556756             27.13368           27.53932
# 3          -0.591092       -0.578498             43.11939           27.53932
# 4          -0.591092       -0.577610             27.96205           27.53932
#
#     Hardness      dCOM     rCo-O
# 0 -39.156000  3.337480  3.856084
# 1 -39.532500  3.314513  4.150980
# 2 -37.085250  3.312872  4.065847
# 3 -37.744125  3.333984  4.033683
# 4 -38.089250  3.328151  3.818543
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 903 entries, 0 to 902
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           903 non-null    int64
#  1   Name                 903 non-null    object
#  2   CoCp2 energy         903 non-null    float64
#  3   CoCp name            903 non-null    object
#  4   CoCp energy          903 non-null    float64
#  5   Cp name              903 non-null    object
#  6   Cp energy            903 non-null    float64
#  7   BDE                  903 non-null    float64
#  8   Dipole moment        903 non-null    float64
#  9   CoCp2 HOMO energy    903 non-null    float64
#  10  CoCp2 LUMO energy    903 non-null    float64
#  11  CoCp HOMO energy     903 non-null    float64
#  12  CoCp LUMO energy     903 non-null    float64
#  13  Cp HOMO energy       903 non-null    float64
#  14  Cp LUMO energy       903 non-null    float64
#  15  CoCp H charge        903 non-null    float64
#  16  Cp H charge          903 non-null    float64
#  17  CoCp proton afinity  903 non-null    float64
#  18  Cp proton afinity    903 non-null    float64
#  19  proton afinity       903 non-null    float64
#  20  CoCp polarizability  903 non-null    float64
#  21  Cp polarizability    903 non-null    float64
#  22  Hardness             903 non-null    float64
#  23  dCOM                 903 non-null    float64
#  24  rCo-O                903 non-null    float64
# dtypes: float64(21), int64(1), object(3)
# memory usage: 176.5+ KB

# %%
ml_df=df.copy()

# %%
ml_df=ml_df.drop(columns=['Unnamed: 0'], axis = 1)
ml_df.head()
# Out:
#                             Name  CoCp2 energy CoCp name  CoCp energy  \
# 0   Co(Cp-N(CH₃)₂)(Cp-N(CH₃)₂)OH  -2113.503825   N(CH₃)₂ -1785.987408
# 1      Co(Cp-N(CH₃)₂)(Cp-OCH₃)OH  -2094.048389      OCH₃ -1766.531474
# 2  Co(Cp-N(CH₃)₂)(Cp-O(CO)CH₃)OH  -2207.402596  O(CO)CH₃ -1879.885018
# 3   Co(Cp-N(CH₃)₂)(Cp-P(CH₃)₂)OH  -2400.122408   P(CH₃)₂ -2072.607246
# 4    Co(Cp-N(CH₃)₂)(Cp-S(CH₃))OH  -2417.026291    S(CH₃) -2089.514536
#
#    Cp name   Cp energy        BDE  Dipole moment  CoCp2 HOMO energy  \
# 0  N(CH₃)₂ -327.488954  17.233174        15.5954            -0.1803
# 1  N(CH₃)₂ -327.488954  17.545539        14.9760            -0.1867
# 2  N(CH₃)₂ -327.488954  17.961810        18.7135            -0.1849
# 3  N(CH₃)₂ -327.488954  16.445457        19.9044            -0.1862
# 4  N(CH₃)₂ -327.488954  14.308038        14.9101            -0.1868
#
#    CoCp2 LUMO energy  ...  CoCp H charge  Cp H charge  CoCp proton afinity  \
# 0            -0.0555  ...       0.011840      0.01184            -0.591092
# 1            -0.0607  ...      -0.015190      0.01184            -0.585828
# 2            -0.0667  ...       0.071736      0.01184            -0.522421
# 3            -0.0659  ...      -0.059590      0.01184            -0.565904
# 4            -0.0654  ...       0.019722      0.01184            -0.564128
#
#    Cp proton afinity  proton afinity  CoCp polarizability  Cp polarizability  \
# 0          -0.591092       -0.591092             27.53932           27.53932
# 1          -0.591092       -0.588460             18.01558           27.53932
# 2          -0.591092       -0.556756             27.13368           27.53932
# 3          -0.591092       -0.578498             43.11939           27.53932
# 4          -0.591092       -0.577610             27.96205           27.53932
#
#     Hardness      dCOM     rCo-O
# 0 -39.156000  3.337480  3.856084
# 1 -39.532500  3.314513  4.150980
# 2 -37.085250  3.312872  4.065847
# 3 -37.744125  3.333984  4.033683
# 4 -38.089250  3.328151  3.818543
#
# [5 rows x 24 columns]

# %% [markdown]
# # Filter Data

# %%
#BDE data greater than 3kcal/mol
drop_bde = (ml_df[ml_df['BDE']<=3])
len(drop_bde)
# Out:
# 30

# %%
drop_bde['Name']
# Out:
# 290            Co(Cp-C₂H)(Cp-CBr₃)OH
# 450             Co(Cp-Cl)(Cp-CBr₃)OH
# 479             Co(Cp-Br)(Cp-CBr₃)OH
# 507              Co(Cp-F)(Cp-CBr₃)OH
# 534      Co(Cp-(CO)NHCH₃)(Cp-CBr₃)OH
# 585       Co(Cp-(CO)OCH₃)(Cp-CBr₃)OH
# 632          Co(Cp-(CO)H)(Cp-CBr₃)OH
# 651        Co(Cp-(CO)F)(Cp-(CO)Cl)OH
# 654          Co(Cp-(CO)F)(Cp-CBr₃)OH
# 657           Co(Cp-(CO)F)(Cp-NO₂)OH
# 658        Co(Cp-(CO)F)(Cp-SOOCF₃)OH
# 672       Co(Cp-(CO)Cl)(Cp-(CO)Cl)OH
# 675         Co(Cp-(CO)Cl)(Cp-CBr₃)OH
# 676           Co(Cp-(CO)Cl)(Cp-CN)OH
# 678          Co(Cp-(CO)Cl)(Cp-NO₂)OH
# 679       Co(Cp-(CO)Cl)(Cp-SOOCF₃)OH
# 695            Co(Cp-CF₃)(Cp-CBr₃)OH
# 714           Co(Cp-CCl₃)(Cp-CBr₃)OH
# 732           Co(Cp-CBr₃)(Cp-CBr₃)OH
# 733             Co(Cp-CBr₃)(Cp-CN)OH
# 734         Co(Cp-CBr₃)(Cp-SOOCH₃)OH
# 735            Co(Cp-CBr₃)(Cp-NO₂)OH
# 736         Co(Cp-CBr₃)(Cp-SOOCF₃)OH
# 740        Co(Cp-CBr₃)(Cp-o-PhCF₃)OH
# 745    Co(Cp-CBr₃)(Cp-op-Ph(CH₃)₃)OH
# 752              Co(Cp-CN)(Cp-NO₂)OH
# 753           Co(Cp-CN)(Cp-SOOCF₃)OH
# 783             Co(Cp-NO₂)(Cp-NO₂)OH
# 784          Co(Cp-NO₂)(Cp-SOOCF₃)OH
# 798       Co(Cp-SOOCF₃)(Cp-SOOCF₃)OH
# Name: Name, dtype: object

# %%
ml_df = ml_df[ml_df['BDE']>3]
len(ml_df)
# Out:
# 873

# %%
ml_df.columns
# Out:
# Index(['Name', 'CoCp2 energy', 'CoCp name', 'CoCp energy', 'Cp name',
#        'Cp energy', 'BDE', 'Dipole moment', 'CoCp2 HOMO energy',
#        'CoCp2 LUMO energy', 'CoCp HOMO energy', 'CoCp LUMO energy',
#        'Cp HOMO energy', 'Cp LUMO energy', 'CoCp H charge', 'Cp H charge',
#        'CoCp proton afinity', 'Cp proton afinity', 'proton afinity',
#        'CoCp polarizability', 'Cp polarizability', 'Hardness', 'dCOM',
#        'rCo-O'],
#       dtype='object')

# %%
frag = ml_df[['Name', 'CoCp name', 'Cp name',
       'BDE', 'CoCp2 HOMO energy',
       'CoCp2 LUMO energy', 'CoCp HOMO energy', 'CoCp LUMO energy',
       'Cp HOMO energy', 'Cp LUMO energy', 'CoCp H charge', 'Cp H charge',
       'CoCp proton afinity', 'Cp proton afinity']]
frag.head()
# Out:
#                             Name CoCp name  Cp name        BDE  \
# 0   Co(Cp-N(CH₃)₂)(Cp-N(CH₃)₂)OH   N(CH₃)₂  N(CH₃)₂  17.233174
# 1      Co(Cp-N(CH₃)₂)(Cp-OCH₃)OH      OCH₃  N(CH₃)₂  17.545539
# 2  Co(Cp-N(CH₃)₂)(Cp-O(CO)CH₃)OH  O(CO)CH₃  N(CH₃)₂  17.961810
# 3   Co(Cp-N(CH₃)₂)(Cp-P(CH₃)₂)OH   P(CH₃)₂  N(CH₃)₂  16.445457
# 4    Co(Cp-N(CH₃)₂)(Cp-S(CH₃))OH    S(CH₃)  N(CH₃)₂  14.308038
#
#    CoCp2 HOMO energy  CoCp2 LUMO energy  CoCp HOMO energy  CoCp LUMO energy  \
# 0            -0.1803            -0.0555           -0.1787           -0.0719
# 1            -0.1867            -0.0607           -0.1935           -0.0727
# 2            -0.1849            -0.0667           -0.2170           -0.0855
# 3            -0.1862            -0.0659           -0.2133           -0.0814
# 4            -0.1868            -0.0654           -0.2015           -0.0817
#
#    Cp HOMO energy  Cp LUMO energy  CoCp H charge  Cp H charge  \
# 0         -0.1594         -0.0809       0.011840      0.01184
# 1         -0.1594         -0.0809      -0.015190      0.01184
# 2         -0.1594         -0.0809       0.071736      0.01184
# 3         -0.1594         -0.0809      -0.059590      0.01184
# 4         -0.1594         -0.0809       0.019722      0.01184
#
#    CoCp proton afinity  Cp proton afinity
# 0            -0.591092          -0.591092
# 1            -0.585828          -0.591092
# 2            -0.522421          -0.591092
# 3            -0.565904          -0.591092
# 4            -0.564128          -0.591092

# %%
corr = abs(frag.corr())
plt.figure(figsize=[16,14])
sns.heatmap(corr, cmap="YlGnBu",  vmin=0.0, vmax=1.0,annot = True, annot_kws={'size': 15})
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.title('Correlation between features related to fragments', fontsize = 18, fontweight = 'bold');
# Out:
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %% [markdown]
# # Statistics

# %%
ml_df.describe()
# Out:
#        CoCp2 energy  CoCp energy    Cp energy         BDE  Dipole moment  \
# count    873.000000   873.000000   873.000000  873.000000     873.000000
# mean   -2885.015296 -2078.544199  -806.446835   15.224432      16.170617
# std     1343.930437   778.250606  1106.634781    6.629545       3.231558
# min   -10408.735637 -9411.126546 -7952.631083    3.185810       4.493000
# 25%    -2880.695616 -2220.117477  -768.161154   10.742214      14.038600
# 50%    -2567.428016 -1879.885018  -542.529457   14.245329      16.331700
# 75%    -2283.371861 -1766.531474  -397.996994   18.345363      18.211100
# max    -1845.520993 -1652.003971  -193.474683   42.413274      27.728700
#
#        CoCp2 HOMO energy  CoCp2 LUMO energy  CoCp HOMO energy  \
# count         873.000000         873.000000        873.000000
# mean           -0.191159          -0.086005         -0.214888
# std             0.006312           0.011437          0.013198
# min            -0.223500          -0.118800         -0.237800
# 25%            -0.191500          -0.093000         -0.224500
# 50%            -0.190000          -0.084900         -0.213300
# 75%            -0.188400          -0.078200         -0.204500
# max            -0.180300          -0.054800         -0.171600
#
#        CoCp LUMO energy  Cp HOMO energy  ...  CoCp H charge  Cp H charge  \
# count        873.000000      873.000000  ...     873.000000   873.000000
# mean          -0.085469       -0.200897  ...       0.034738     0.020129
# std            0.008885        0.021833  ...       0.062240     0.050861
# min           -0.106800       -0.246900  ...      -0.081960    -0.081960
# 25%           -0.092000       -0.216600  ...      -0.024960    -0.015190
# 50%           -0.085100       -0.201000  ...       0.038080     0.011965
# 75%           -0.079400       -0.188600  ...       0.081263     0.057107
# max           -0.063300       -0.155200  ...       0.160449     0.160449
#
#        CoCp proton afinity  Cp proton afinity  proton afinity  \
# count           873.000000         873.000000      873.000000
# mean             -0.375526          -0.455575       -0.415550
# std               0.265355           0.227465        0.173252
# min              -0.599383          -0.599383       -0.599383
# 25%              -0.575828          -0.579566       -0.571430
# 50%              -0.559224          -0.569191       -0.534932
# 75%               0.000000          -0.522421       -0.286324
# max               0.000000           0.000000        0.000000
#
#        CoCp polarizability  Cp polarizability    Hardness        dCOM  \
# count           873.000000         873.000000  873.000000  873.000000
# mean             32.582851          48.667438  -32.992052    3.300790
# std              29.889890          33.700939    3.965526    0.010104
# min               0.265420           0.265420  -46.529125    3.282637
# 25%              12.952910          22.669890  -35.328250    3.292941
# 50%              24.041310          52.745580  -33.100625    3.298622
# 75%              43.981350          60.200450  -30.465125    3.305980
# max             150.643000         150.643000  -22.935125    3.337480
#
#             rCo-O
# count  873.000000
# mean     4.008424
# std      0.159475
# min      3.691918
# 25%      3.896393
# 50%      3.994029
# 75%      4.104762
# max      4.725310
#
# [8 rows x 21 columns]

# %%
#checking for duplicates
ml_df.duplicated().sum()
# Out:
# 0

# %%
#checking for missing values
ml_df.isna().sum().sum()
# Out:
# 0

# %%
ml_df.head()
# Out:
#                             Name  CoCp2 energy CoCp name  CoCp energy  \
# 0   Co(Cp-N(CH₃)₂)(Cp-N(CH₃)₂)OH  -2113.503825   N(CH₃)₂ -1785.987408
# 1      Co(Cp-N(CH₃)₂)(Cp-OCH₃)OH  -2094.048389      OCH₃ -1766.531474
# 2  Co(Cp-N(CH₃)₂)(Cp-O(CO)CH₃)OH  -2207.402596  O(CO)CH₃ -1879.885018
# 3   Co(Cp-N(CH₃)₂)(Cp-P(CH₃)₂)OH  -2400.122408   P(CH₃)₂ -2072.607246
# 4    Co(Cp-N(CH₃)₂)(Cp-S(CH₃))OH  -2417.026291    S(CH₃) -2089.514536
#
#    Cp name   Cp energy        BDE  Dipole moment  CoCp2 HOMO energy  \
# 0  N(CH₃)₂ -327.488954  17.233174        15.5954            -0.1803
# 1  N(CH₃)₂ -327.488954  17.545539        14.9760            -0.1867
# 2  N(CH₃)₂ -327.488954  17.961810        18.7135            -0.1849
# 3  N(CH₃)₂ -327.488954  16.445457        19.9044            -0.1862
# 4  N(CH₃)₂ -327.488954  14.308038        14.9101            -0.1868
#
#    CoCp2 LUMO energy  ...  CoCp H charge  Cp H charge  CoCp proton afinity  \
# 0            -0.0555  ...       0.011840      0.01184            -0.591092
# 1            -0.0607  ...      -0.015190      0.01184            -0.585828
# 2            -0.0667  ...       0.071736      0.01184            -0.522421
# 3            -0.0659  ...      -0.059590      0.01184            -0.565904
# 4            -0.0654  ...       0.019722      0.01184            -0.564128
#
#    Cp proton afinity  proton afinity  CoCp polarizability  Cp polarizability  \
# 0          -0.591092       -0.591092             27.53932           27.53932
# 1          -0.591092       -0.588460             18.01558           27.53932
# 2          -0.591092       -0.556756             27.13368           27.53932
# 3          -0.591092       -0.578498             43.11939           27.53932
# 4          -0.591092       -0.577610             27.96205           27.53932
#
#     Hardness      dCOM     rCo-O
# 0 -39.156000  3.337480  3.856084
# 1 -39.532500  3.314513  4.150980
# 2 -37.085250  3.312872  4.065847
# 3 -37.744125  3.333984  4.033683
# 4 -38.089250  3.328151  3.818543
#
# [5 rows x 24 columns]

# %%
ml_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 873 entries, 0 to 902
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 873 non-null    object
#  1   CoCp2 energy         873 non-null    float64
#  2   CoCp name            873 non-null    object
#  3   CoCp energy          873 non-null    float64
#  4   Cp name              873 non-null    object
#  5   Cp energy            873 non-null    float64
#  6   BDE                  873 non-null    float64
#  7   Dipole moment        873 non-null    float64
#  8   CoCp2 HOMO energy    873 non-null    float64
#  9   CoCp2 LUMO energy    873 non-null    float64
#  10  CoCp HOMO energy     873 non-null    float64
#  11  CoCp LUMO energy     873 non-null    float64
#  12  Cp HOMO energy       873 non-null    float64
#  13  Cp LUMO energy       873 non-null    float64
#  14  CoCp H charge        873 non-null    float64
#  15  Cp H charge          873 non-null    float64
#  16  CoCp proton afinity  873 non-null    float64
#  17  Cp proton afinity    873 non-null    float64
#  18  proton afinity       873 non-null    float64
#  19  CoCp polarizability  873 non-null    float64
#  20  Cp polarizability    873 non-null    float64
#  21  Hardness             873 non-null    float64
#  22  dCOM                 873 non-null    float64
#  23  rCo-O                873 non-null    float64
# dtypes: float64(21), object(3)
# memory usage: 170.5+ KB

# %% [markdown]
# # Validate Split

# %%
y = ml_df['BDE']
X = ml_df[['CoCp HOMO energy', 'CoCp LUMO energy',
           'Cp HOMO energy', 'Cp LUMO energy',
           'CoCp H charge', 'Cp H charge',
           'CoCp proton afinity', 'Cp proton afinity']]

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.20, random_state = 42)

# %%
X_train
# Out:
#      CoCp HOMO energy  CoCp LUMO energy  Cp HOMO energy  Cp LUMO energy  \
# 549           -0.2192           -0.0863         -0.1552         -0.0768
# 399           -0.2009           -0.0945         -0.2027         -0.1250
# 794           -0.2350           -0.1068         -0.1815         -0.1118
# 313           -0.2053           -0.0778         -0.2190         -0.1256
# 327           -0.2053           -0.0778         -0.2435         -0.1513
# ..                ...               ...             ...             ...
# 106           -0.2297           -0.0944         -0.2092         -0.1170
# 270           -0.2003           -0.0802         -0.1552         -0.0768
# 890           -0.2060           -0.0794         -0.1552         -0.0768
# 436           -0.2131           -0.0789         -0.1952         -0.1163
# 102           -0.2346           -0.0965         -0.2092         -0.1170
#
#      CoCp H charge  Cp H charge  CoCp proton afinity  Cp proton afinity
# 549       0.031767    -0.081960            -0.507003          -0.587131
# 399      -0.033870     0.024095            -0.598052          -0.569191
# 794       0.160449    -0.041080             0.000000          -0.582702
# 313      -0.024960     0.083209            -0.560672           0.000000
# 327      -0.024960     0.160449            -0.560672           0.000000
# ..             ...          ...                  ...                ...
# 106       0.156189     0.071736             0.000000          -0.522421
# 270       0.008470    -0.081960            -0.577901          -0.587131
# 890      -0.042140    -0.081960            -0.532771          -0.587131
# 436      -0.050620    -0.040350            -0.582188          -0.577526
# 102       0.121657     0.071736             0.000000          -0.522421
#
# [698 rows x 8 columns]

# %% [markdown]
# # Functions

# %% [markdown]
# ## Evaluvation

# %%
#function for evaluation
def eval_model(pipe, X_train=X_train, y_train=y_train, X_test=X_test , y_test= y_test):
  eval_results = pd.DataFrame(columns = ['Metrics','Train Score', 'Test Score'])
  train_mae = mean_absolute_error(y_train, pipe.predict(X_train))
  test_mae = mean_absolute_error(y_test, pipe.predict(X_test))

  train_mse = mean_squared_error(y_train, pipe.predict(X_train))
  test_mse = mean_squared_error(y_test, pipe.predict(X_test))

  train_rmse = np.sqrt(train_mse)
  test_rmse = np.sqrt(test_mse)

  train_r2 = r2_score(y_train, pipe.predict(X_train))
  test_r2 = r2_score(y_test, pipe.predict(X_test))

  eval_results.loc[1, 'Metrics'] = 'MAE'
  eval_results.loc[2, 'Metrics'] = 'MSE'
  eval_results.loc[3, 'Metrics'] = 'RMSE'
  eval_results.loc[4, 'Metrics'] = 'R2'

  eval_results.loc[1, 'Train Score'] = train_mae
  eval_results.loc[2, 'Train Score'] = train_mse
  eval_results.loc[3, 'Train Score'] = train_rmse
  eval_results.loc[4, 'Train Score'] = train_r2

  eval_results.loc[1, 'Test Score'] = test_mae
  eval_results.loc[2, 'Test Score'] = test_mse
  eval_results.loc[3, 'Test Score'] = test_rmse
  eval_results.loc[4, 'Test Score'] = test_r2

  return eval_results

# %%
#function for final evaluation
def eval_model_final(pipe, 
                     X_train=X_train, y_train=y_train, 
                     X_test=X_test , y_test= y_test):

  train_mse = mean_squared_error(y_train, pipe.predict(X_train))
  test_mse = mean_squared_error(y_test, pipe.predict(X_test))

  train_rmse = np.sqrt(train_mse)
  test_rmse = np.sqrt(test_mse)

  train_r2 = r2_score(y_train, pipe.predict(X_train))
  test_r2 = r2_score(y_test, pipe.predict(X_test))

  return (round(train_r2,6), round(test_r2,6), round(train_rmse,6), round(test_rmse,6))

# %% [markdown]
# ## Plot

# %%
def train_test_plot(model_name, pipe,  X_train=X_train, y_train=y_train, X_test=X_test , y_test= y_test):
  fig, axes = plt.subplots(nrows = 1, ncols=2, figsize=(12,4))
#subplot1
  ax = sns.regplot(x = y_train, 
                   y = pipe.predict(X_train), 
                   line_kws = {'color':'black', 'ls': ':', 'label' :f'R$^2$ = {round(r2_score(y_train, pipe.predict(X_train)), 6)}'}, 
                   ax=axes[0],
                   )
  axes[0].set_title('Train Data', fontweight = 'bold')
  axes[0].set_xlabel('Actual BDE (kcal/mol)')
  axes[0].set_ylabel('Predicted BDE (kcal/mol)');

#subplot2
  ax = sns.regplot(x = y_test, 
                   y = pipe.predict(X_test), 
                   line_kws = {'color':'black', 'ls': ':', 
                   'label' : f'R$^2$ = {round(r2_score(y_test, pipe.predict(X_test)), 6)}'}, 
                   ax=axes[1])
  axes[1].set_title('Test Data', fontweight = 'bold')
  axes[1].set_xlabel('Actual BDE (kcal/mol)')
  axes[1].set_ylabel('Predicted BDE (kcal/mol)')
  
  fig.suptitle(f'Train and Test Results of {model_name}', fontsize = 20, fontweight = 'bold', y = 1.1)
  [ax.legend() for ax in axes];
  return (fig, axes)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Instantiate colimn transformers

# %%
scaler = StandardScaler()

# %% [markdown]
# # Linear Regression Model

# %%
lr = LinearRegression()
lr_pipe = make_pipeline(scaler, lr)
lr_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %%
#evaluvation of linear rigression
eval_model(lr_pipe)
# Out:
#   Metrics Train Score Test Score
# 1     MAE    2.971097    3.00382
# 2     MSE   22.993486  23.161225
# 3    RMSE    4.795152   4.812611
# 4      R2    0.483041   0.443097

# %%
train_test_plot('Linear Regression Model', lr_pipe)
# Out:
# (<Figure size 1200x400 with 2 Axes>,
#  array([<AxesSubplot: title={'center': 'Train Data'}, xlabel='Actual BDE (kcal/mol)', ylabel='Predicted BDE (kcal/mol)'>,
#         <AxesSubplot: title={'center': 'Test Data'}, xlabel='Actual BDE (kcal/mol)', ylabel='Predicted BDE (kcal/mol)'>],
#        dtype=object))

# %% [markdown]
# # Decision Tree Model

# %%
dt = DecisionTreeRegressor(random_state = 42)
dt_pipe = make_pipeline(scaler, dt)
dt_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('decisiontreeregressor',
#                  DecisionTreeRegressor(random_state=42))])

# %%
#evaluvation of initial decision tree
eval_model(dt_pipe)
# Out:
#   Metrics Train Score Test Score
# 1     MAE         0.0   1.985875
# 2     MSE         0.0  16.553272
# 3    RMSE         0.0   4.068571
# 4      R2         1.0   0.601983

# %%
train_test_plot('Initial Decision Tree Model', dt_pipe)
# Out:
# (<Figure size 1200x400 with 2 Axes>,
#  array([<AxesSubplot: title={'center': 'Train Data'}, xlabel='Actual BDE (kcal/mol)', ylabel='Predicted BDE (kcal/mol)'>,
#         <AxesSubplot: title={'center': 'Test Data'}, xlabel='Actual BDE (kcal/mol)', ylabel='Predicted BDE (kcal/mol)'>],
#        dtype=object))

# %% [markdown]
# # Bagged Tree Model

# %%
bt = BaggingRegressor(random_state = 42)
bt_pipe = make_pipeline(scaler, bt)
bt_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('baggingregressor', BaggingRegressor(random_state=42))])

# %%
#evaluvation of initial bagged tree
eval_model(bt_pipe)
# Out:
#   Metrics Train Score Test Score
# 1     MAE    0.647415   1.637895
# 2     MSE    1.425825   7.487177
# 3    RMSE    1.194079   2.736271
# 4      R2    0.967943   0.819974

# %%
train_test_plot('Initial Bagged Tree Model', bt_pipe)
# Out:
# (<Figure size 1200x400 with 2 Axes>,
#  array([<AxesSubplot: title={'center': 'Train Data'}, xlabel='Actual BDE (kcal/mol)', ylabel='Predicted BDE (kcal/mol)'>,
#         <AxesSubplot: title={'center': 'Test Data'}, xlabel='Actual BDE (kcal/mol)', ylabel='Predicted BDE (kcal/mol)'>],
#        dtype=object))

# %% [markdown]
# # K-Nearest Neighbors Model

# %%
knn = KNeighborsRegressor()
knn_pipe = make_pipeline(scaler, knn)
knn_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('kneighborsregressor', KNeighborsRegressor())])

# %%
#evaluvation of initial knn
eval_model(knn_pipe)
# Out:
#   Metrics Train Score Test Score
# 1     MAE    2.272853   3.034125
# 2     MSE   12.968546  21.787029
# 3    RMSE    3.601187   4.667658
# 4      R2     0.70843   0.476139

# %%
train_test_plot('Initial KNN Model', knn_pipe)
# Out:
# (<Figure size 1200x400 with 2 Axes>,
#  array([<AxesSubplot: title={'center': 'Train Data'}, xlabel='Actual BDE (kcal/mol)', ylabel='Predicted BDE (kcal/mol)'>,
#         <AxesSubplot: title={'center': 'Test Data'}, xlabel='Actual BDE (kcal/mol)', ylabel='Predicted BDE (kcal/mol)'>],
#        dtype=object))

# %% [markdown]
# # Random Forest Model

# %%
rf = RandomForestRegressor(random_state= 42)
rf_pipe = make_pipeline(scaler, rf)
rf_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestregressor',
#                  RandomForestRegressor(random_state=42))])

# %%
#evaluvation of initial bagged tree
eval_model(rf_pipe)
# Out:
#   Metrics Train Score Test Score
# 1     MAE    0.533152   1.536723
# 2     MSE    0.783361   7.125892
# 3    RMSE    0.885077   2.669437
# 4      R2    0.982388   0.828661

# %%
train_test_plot('Initial Random Forest Model', rf_pipe)
# Out:
# (<Figure size 1200x400 with 2 Axes>,
#  array([<AxesSubplot: title={'center': 'Train Data'}, xlabel='Actual BDE (kcal/mol)', ylabel='Predicted BDE (kcal/mol)'>,
#         <AxesSubplot: title={'center': 'Test Data'}, xlabel='Actual BDE (kcal/mol)', ylabel='Predicted BDE (kcal/mol)'>],
#        dtype=object))

# %% [markdown]
# # Support Vector Regression Model

# %%
svg = SVR()
svg_pipe = make_pipeline(scaler, svg)
svg_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('svr', SVR())])

# %%
#evaluvation of initial svg
eval_model(svg_pipe)
# Out:
#   Metrics Train Score Test Score
# 1     MAE    2.659211   2.808357
# 2     MSE   23.383845  24.764532
# 3    RMSE    4.835685   4.976397
# 4      R2    0.474264   0.404546

# %%
train_test_plot('Initial SVG Model', svg_pipe)
# Out:
# (<Figure size 1200x400 with 2 Axes>,
#  array([<AxesSubplot: title={'center': 'Train Data'}, xlabel='Actual BDE (kcal/mol)', ylabel='Predicted BDE (kcal/mol)'>,
#         <AxesSubplot: title={'center': 'Test Data'}, xlabel='Actual BDE (kcal/mol)', ylabel='Predicted BDE (kcal/mol)'>],
#        dtype=object))

# %% [markdown]
# # XG Boost

# %%
xgb = XGBRegressor(random_state= 42)
xgb_pipe = make_pipeline(scaler, xgb)
xgb_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('xgbregressor',
#                  XGBRegressor(base_score=0.5, booster='gbtree',
#                               colsample_bylevel=1, colsample_bynode=1,
#                               colsample_bytree=1, enable_categorical=False,
#                               gamma=0, gpu_id=-1, importance_type=None,
#                               interaction_constraints='',
#                               learning_rate=0.300000012, max_delta_step=0,
#                               max_depth=6, min_child_weight=1, missing=nan,
#                               monotone_constraints='()', n_estimators=100,
#                               n_jobs=12, num_parallel_tree=1, predictor='auto',
#                               random_state=42, reg_alpha=0, reg_lambda=1,
#                               scale_pos_weight=1, subsample=1,
#                               tree_method='exact', validate_parameters=1,
#                               verbosity=None))])

# %%
#evaluvation of initial xgb
eval_model(xgb_pipe)
# Out:
#   Metrics Train Score Test Score
# 1     MAE     0.09272   1.286775
# 2     MSE    0.017899    6.51919
# 3    RMSE    0.133788    2.55327
# 4      R2    0.999598   0.843249

# %%
train_test_plot('Initial XG Boost Model', xgb_pipe)
# Out:
# (<Figure size 1200x400 with 2 Axes>,
#  array([<AxesSubplot: title={'center': 'Train Data'}, xlabel='Actual BDE (kcal/mol)', ylabel='Predicted BDE (kcal/mol)'>,
#         <AxesSubplot: title={'center': 'Test Data'}, xlabel='Actual BDE (kcal/mol)', ylabel='Predicted BDE (kcal/mol)'>],
#        dtype=object))

# %% [markdown]
# # Evaluvation of initial models

# %%
model = ['Linear Regression', 'Decision Tree', 'Bagged Tree', 'KNN', 'Random Forest', 'SVG', 'XG Boost']
pipe = [lr_pipe, dt_pipe, bt_pipe, knn_pipe, rf_pipe, svg_pipe, xgb_pipe]
final_eval_results = pd.DataFrame(columns = ['Model','Train R2', 'Test R2', 'Train RMSE (kcal/mol)', 'Test RMSE (kcal/mol)'])

for i in range(len(model)):
  final_eval_results.loc[i, 'Model'] = model[i]
  final_eval_results.loc[i,'Train R2'], final_eval_results.loc[i,'Test R2'], final_eval_results.loc[i,'Train RMSE (kcal/mol)'], final_eval_results.loc[i,'Test RMSE (kcal/mol)'] = eval_model_final(pipe[i])

# %%
final_eval_results.set_index('Model', inplace = True) 
final_eval_results
# Out:
#                    Train R2   Test R2 Train RMSE (kcal/mol)  \
# Model
# Linear Regression  0.483041  0.443097              4.795152
# Decision Tree           1.0  0.601983                   0.0
# Bagged Tree        0.967943  0.819974              1.194079
# KNN                 0.70843  0.476139              3.601187
# Random Forest      0.982388  0.828661              0.885077
# SVG                0.474264  0.404546              4.835685
# XG Boost           0.999598  0.843249              0.133788
#
#                   Test RMSE (kcal/mol)
# Model
# Linear Regression             4.812611
# Decision Tree                 4.068571
# Bagged Tree                   2.736271
# KNN                           4.667658
# Random Forest                 2.669437
# SVG                           4.976397
# XG Boost                       2.55327

# %% [markdown]
# - According to the train and test RMSE values for the models;
#   - all models have overfilling issue and decision tree has the highest overfittin problem.
# - Out of these 7 models, XG boost, random forest and bagged tree are selected based on the test R$^2$ score to do further optimizations.

# %% [markdown]
# # Tunning Hyperparametrs and cross validation of models

# %% [markdown]
# ## For XG Boost

# %%
#parametrs of XG boost model
xgb_pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('standardscaler', StandardScaler()),
#   ('xgbregressor',
#    XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#                 gamma=0, gpu_id=-1, importance_type=None,
#                 interaction_constraints='', learning_rate=0.300000012,
#                 max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#                 monotone_constraints='()', n_estimators=100, n_jobs=12,
#                 num_parallel_tree=1, predictor='auto', random_state=42,
#                 reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#                 tree_method='exact', validate_parameters=1, verbosity=None))],
#  'verbose': False,
#  'standardscaler': StandardScaler(),
#  'xgbregressor': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=12,
#               num_parallel_tree=1, predictor='auto', random_state=42,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None),
#  'standardscaler__copy': True,
#  'standardscaler__with_mean': True,
#  'standardscaler__with_std': True,
#  'xgbregressor__objective': 'reg:squarederror',
#  'xgbregressor__base_score': 0.5,
#  'xgbregressor__booster': 'gbtree',
#  'xgbregressor__colsample_bylevel': 1,
#  'xgbregressor__colsample_bynode': 1,
#  'xgbregressor__colsample_bytree': 1,
#  'xgbregressor__enable_categorical': False,
#  'xgbregressor__gamma': 0,
#  'xgbregressor__gpu_id': -1,
#  'xgbregressor__importance_type': None,
#  'xgbregressor__interaction_constraints': '',
#  'xgbregressor__learning_rate': 0.300000012,
#  'xgbregressor__max_delta_step': 0,
#  'xgbregressor__max_depth': 6,
#  'xgbregressor__min_child_weight': 1,
#  'xgbregressor__missing': nan,
#  'xgbregressor__monotone_constraints': '()',
#  'xgbregressor__n_estimators': 100,
#  'xgbregressor__n_jobs': 12,
#  'xgbregressor__num_parallel_tree': 1,
#  'xgbregressor__predictor': 'auto',
#  'xgbregressor__random_state': 42,
#  'xgbregressor__reg_alpha': 0,
#  'xgbregressor__reg_lambda': 1,
#  'xgbregressor__scale_pos_weight': 1,
#  'xgbregressor__subsample': 1,
#  'xgbregressor__tree_method': 'exact',
#  'xgbregressor__validate_parameters': 1,
#  'xgbregressor__verbosity': None}

# %%
xgb_param_grid = {'xgbregressor__max_depth': [3,4,5],
                 'xgbregressor__learning_rate':[0.26],
                  'xgbregressor__n_estimators': [125]
                   }

# %%
xgb_pipe_gs = GridSearchCV(xgb_pipe, xgb_param_grid, cv=5)
xgb_pipe_gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('xgbregressor',
#                                         XGBRegressor(base_score=0.5,
#                                                      booster='gbtree',
#                                                      colsample_bylevel=1,
#                                                      colsample_bynode=1,
#                                                      colsample_bytree=1,
#                                                      enable_categorical=False,
#                                                      gamma=0, gpu_id=-1,
#                                                      importance_type=None,
#                                                      interaction_constraints='',
#                                                      learning_rate=0.300000012,
#                                                      max_delta_step=0,
#                                                      max_depth=6,
#                                                      min_c...
#                                                      missing=nan,
#                                                      monotone_constraints='()',
#                                                      n_estimators=100,
#                                                      n_jobs=12,
#                                                      num_parallel_tree=1,
#                                                      predictor='auto',
#                                                      random_state=42,
#                                                      reg_alpha=0, reg_lambda=1,
#                                                      scale_pos_weight=1,
#                                                      subsample=1,
#                                                      tree_method='exact',
#                                                      validate_parameters=1,
#                                                      verbosity=None))]),
#              param_grid={'xgbregressor__learning_rate': [0.26],
#                          'xgbregressor__max_depth': [3, 4, 5],
#                          'xgbregressor__n_estimators': [125]})

# %%
print(f'Best parameters: {xgb_pipe_gs.best_params_}')
# Out:
# Best parameters: {'xgbregressor__learning_rate': 0.26, 'xgbregressor__max_depth': 4, 'xgbregressor__n_estimators': 125}

# %%
xgb_opt = xgb_pipe_gs.best_estimator_
xgb_opt.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('xgbregressor',
#                  XGBRegressor(base_score=0.5, booster='gbtree',
#                               colsample_bylevel=1, colsample_bynode=1,
#                               colsample_bytree=1, enable_categorical=False,
#                               gamma=0, gpu_id=-1, importance_type=None,
#                               interaction_constraints='', learning_rate=0.26,
#                               max_delta_step=0, max_depth=4, min_child_weight=1,
#                               missing=nan, monotone_constraints='()',
#                               n_estimators=125, n_jobs=12, num_parallel_tree=1,
#                               predictor='auto', random_state=42, reg_alpha=0,
#                               reg_lambda=1, scale_pos_weight=1, subsample=1,
#                               tree_method='exact', validate_parameters=1,
#                               verbosity=None))])

# %%
eval_model(xgb_opt)
# Out:
#   Metrics Train Score Test Score
# 1     MAE    0.416275   1.128185
# 2     MSE     0.45568    4.85933
# 3    RMSE    0.675041   2.204389
# 4      R2    0.989755   0.883159

# %%
train_test_plot('Optimized XG Boost Model', xgb_opt)
#plt.savefig('xgb_opt.png')
# Out:
# (<Figure size 1200x400 with 2 Axes>,
#  array([<AxesSubplot: title={'center': 'Train Data'}, xlabel='Actual BDE (kcal/mol)', ylabel='Predicted BDE (kcal/mol)'>,
#         <AxesSubplot: title={'center': 'Test Data'}, xlabel='Actual BDE (kcal/mol)', ylabel='Predicted BDE (kcal/mol)'>],
#        dtype=object))

# %% [markdown]
# ## For Random Forest

# %%
#parametrs of random forest model
rf_pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('standardscaler', StandardScaler()),
#   ('randomforestregressor', RandomForestRegressor(random_state=42))],
#  'verbose': False,
#  'standardscaler': StandardScaler(),
#  'randomforestregressor': RandomForestRegressor(random_state=42),
#  'standardscaler__copy': True,
#  'standardscaler__with_mean': True,
#  'standardscaler__with_std': True,
#  'randomforestregressor__bootstrap': True,
#  'randomforestregressor__ccp_alpha': 0.0,
#  'randomforestregressor__criterion': 'squared_error',
#  'randomforestregressor__max_depth': None,
#  'randomforestregressor__max_features': 1.0,
#  'randomforestregressor__max_leaf_nodes': None,
#  'randomforestregressor__max_samples': None,
#  'randomforestregressor__min_impurity_decrease': 0.0,
#  'randomforestregressor__min_samples_leaf': 1,
#  'randomforestregressor__min_samples_split': 2,
#  'randomforestregressor__min_weight_fraction_leaf': 0.0,
#  'randomforestregressor__n_estimators': 100,
#  'randomforestregressor__n_jobs': None,
#  'randomforestregressor__oob_score': False,
#  'randomforestregressor__random_state': 42,
#  'randomforestregressor__verbose': 0,
#  'randomforestregressor__warm_start': False}

# %%
#maximum max_depth value of estimators of rf 
est_depth = [estimator.get_depth() for estimator in rf.estimators_]
max(est_depth)
# Out:
# 25

# %%
rf_param_grid = {'randomforestregressor__n_estimators':[25,50,75,100,125,150,175,200],
                 'randomforestregressor__max_depth': range(5, 50, 5)}

# %%
rf_pipe_gs = GridSearchCV(rf_pipe, rf_param_grid, cv =5)
rf_pipe_gs.fit(X_train, y_train);

# %%
print(f'Best parameters: {rf_pipe_gs.best_params_}')
# Out:
# Best parameters: {'randomforestregressor__max_depth': 20, 'randomforestregressor__n_estimators': 175}

# %%
rf_opt = rf_pipe_gs.best_estimator_
rf_opt.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestregressor',
#                  RandomForestRegressor(max_depth=20, n_estimators=175,
#                                        random_state=42))])

# %%
eval_model(rf_opt)
# Out:
#   Metrics Train Score Test Score
# 1     MAE    0.519335   1.547154
# 2     MSE    0.748552   7.295829
# 3    RMSE    0.865189   2.701079
# 4      R2     0.98317   0.824575

# %%
train_test_plot('Optimized Random Forest Model', rf_opt)
#plt.savefig('rt_opt.png')
# Out:
# (<Figure size 1200x400 with 2 Axes>,
#  array([<AxesSubplot: title={'center': 'Train Data'}, xlabel='Actual BDE (kcal/mol)', ylabel='Predicted BDE (kcal/mol)'>,
#         <AxesSubplot: title={'center': 'Test Data'}, xlabel='Actual BDE (kcal/mol)', ylabel='Predicted BDE (kcal/mol)'>],
#        dtype=object))

# %% [markdown]
# ## For Bagged Tree

# %%
#parametrs of decision tree model
bt_pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('standardscaler', StandardScaler()),
#   ('baggingregressor', BaggingRegressor(random_state=42))],
#  'verbose': False,
#  'standardscaler': StandardScaler(),
#  'baggingregressor': BaggingRegressor(random_state=42),
#  'standardscaler__copy': True,
#  'standardscaler__with_mean': True,
#  'standardscaler__with_std': True,
#  'baggingregressor__base_estimator': None,
#  'baggingregressor__bootstrap': True,
#  'baggingregressor__bootstrap_features': False,
#  'baggingregressor__max_features': 1.0,
#  'baggingregressor__max_samples': 1.0,
#  'baggingregressor__n_estimators': 10,
#  'baggingregressor__n_jobs': None,
#  'baggingregressor__oob_score': False,
#  'baggingregressor__random_state': 42,
#  'baggingregressor__verbose': 0,
#  'baggingregressor__warm_start': False}

# %%
bt_param_grid = {'baggingregressor__n_estimators':range(10, 80, 10)}

# %%
bt_pipe_gs = GridSearchCV(bt_pipe, bt_param_grid, cv=5)
bt_pipe_gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('baggingregressor',
#                                         BaggingRegressor(random_state=42))]),
#              param_grid={'baggingregressor__n_estimators': range(10, 80, 10)})

# %%
print(f'Best parameters: {bt_pipe_gs.best_params_}')
# Out:
# Best parameters: {'baggingregressor__n_estimators': 70}

# %%
bt_opt = bt_pipe_gs.best_estimator_
bt_opt.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('baggingregressor',
#                  BaggingRegressor(n_estimators=70, random_state=42))])

# %%
eval_model(bt_opt)
# Out:
#   Metrics Train Score Test Score
# 1     MAE    0.541911   1.530736
# 2     MSE    0.795906   7.076622
# 3    RMSE    0.892136   2.660192
# 4      R2    0.982106   0.829845

# %%
train_test_plot('Optimized Bagged Tree Model', bt_opt)
#plt.savefig('bt_opt.png')
# Out:
# (<Figure size 1200x400 with 2 Axes>,
#  array([<AxesSubplot: title={'center': 'Train Data'}, xlabel='Actual BDE (kcal/mol)', ylabel='Predicted BDE (kcal/mol)'>,
#         <AxesSubplot: title={'center': 'Test Data'}, xlabel='Actual BDE (kcal/mol)', ylabel='Predicted BDE (kcal/mol)'>],
#        dtype=object))

# %% [markdown]
# ## Evaluvation of optimized models

# %%
model = ['XG Boost','Random Forest', 'Bagged Tree']
pipe = [xgb_opt, rf_opt, bt_opt]
final_eval_results = pd.DataFrame(columns = ['Model','Train R2', 'Test R2', 'Train RMSE (kcal/mol)', 'Test RMSE (kcal/mol)'])

for i in range(len(model)):
  final_eval_results.loc[i, 'Model'] = model[i]
  final_eval_results.loc[i,'Train R2'], final_eval_results.loc[i,'Test R2'], final_eval_results.loc[i,'Train RMSE (kcal/mol)'], final_eval_results.loc[i,'Test RMSE (kcal/mol)'] = eval_model_final(pipe[i])

# %%
sns.lineplot(data = final_eval_results, x = 'Model', y= 'Train R2', 
             ls = ':', marker = 'o', label = 'Train R$^2$', lw = 2, color = 'blue' )
sns.lineplot(data = final_eval_results, x = 'Model', y= 'Test R2', 
             ls = ':', marker = 'o', label = 'Test R$^2$', lw = 2, color = 'magenta' )
plt.ylabel('R$^2$ Score')
plt.xlabel('Models')
plt.title('Performance of optimized models ', fontsize = 18, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Performance of optimized models ')

# %%
sns.lineplot(data = final_eval_results, x = 'Model', y= 'Train RMSE (kcal/mol)', 
             ls = ':', marker = 'o', label = 'Train RMSE', lw = 2, color = 'blue')
sns.lineplot(data = final_eval_results, x = 'Model', y= 'Test RMSE (kcal/mol)', 
             ls = ':', marker = 'o', label = 'Test RMSE', lw = 2, color = 'magenta')
plt.ylabel('RMSE (kcal/mol)')
plt.xlabel('Models')
plt.title('Performance of optimized models ', fontsize = 18, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Performance of optimized models ')

# %%
final_eval_results.set_index('Model', inplace = True) 
final_eval_results
# Out:
#                Train R2   Test R2 Train RMSE (kcal/mol) Test RMSE (kcal/mol)
# Model
# XG Boost       0.989755  0.883159              0.675041             2.204389
# Random Forest   0.98317  0.824575              0.865189             2.701079
# Bagged Tree    0.982106  0.829845              0.892136             2.660192
